# %%
import numpy as np
np.random.seed(42)
import pandas as pd
import os
from tqdm import tqdm
from scipy.stats import spearmanr, pearsonr
from pingouin import partial_corr
np.random.seed(42)
from itertools import combinations, product
from loading_functions import get_hypothesis_data

# %%
df = pd.read_csv('eeg_mri_cognition_deidentified.csv', index_col=0)
df.columns[:30]
# Out:
# Index(['interval_mri-eeg_abs1', 'report_date_time', 'report_description',
#        'report_status', 'report_type', 'age', 'sex', 'bmi', 'ahi', 'medbenzo',
#        'medantidep', 'medsedative', 'medantieplipetic', 'medstimulant', 'mmse',
#        'mean_gradient_f3-m2_w', 'mean_gradient_f4-m1_w',
#        'mean_gradient_c3-m2_w', 'mean_gradient_o1-m2_w',
#        'slow_bandpower_mean_f_w', 'slow_bandpower_mean_c_w',
#        'slow_bandpower_mean_o_w', 'delta_bandpower_mean_f_w',
#        'delta_bandpower_mean_c_w', 'delta_bandpower_mean_o_w',
#        'slowdelta_bandpower_mean_c_w', 'theta_bandpower_mean_f_w',
#        'theta_bandpower_mean_o_w', 'alpha_bandpower_mean_f_w',
#        'sigma_bandpower_mean_f_w'],
#       dtype='object')

# %%
# clip at 99% percentile:
df['slowdelta_bandpower_total'] = df['slowdelta_bandpower_total'].clip(lower=df['slowdelta_bandpower_total'].quantile(0),
                                                                        upper=df['slowdelta_bandpower_total'].quantile(0.99))


df_all = df.copy()
df_cognition = df[pd.notna(df.mmse)].copy()
print(df_all.shape)
print(df_cognition.shape)
# Out:
# (623, 853)
# (160, 853)

# %%
group_names = {
    'dt_groupall': 'dt all',
    'dt_group1': 'dt within 1 year',
    'dt_group2': 'dt between 1-2.5 years',
    'dt_group3': 'dt between 2.5-7 years',

    'age_groupall': 'age all',
    'age_group1': 'age younger than 60',
    'age_group2': 'age between 60-70',
    'age_group3': 'age older than 70',
}

# %%
# group 1 < 1 year

for df_sel in df_all, df_cognition:
    print('___')
    df_sel['dt_groupall'] = 1
    df_sel['dt_group1'] = df_sel['dt_abs'].apply(lambda x: 1 if x < 1 else 0)
    df_sel['dt_group2'] = df_sel['dt_abs'].apply(lambda x: 1 if x >= 1 and x < 2.5 else 0)
    df_sel['dt_group3'] = df_sel['dt_abs'].apply(lambda x: 1 if x >= 2.5 else 0)
    print(df_sel[['dt_group1', 'dt_group2', 'dt_group3']].sum())

    # age groups:
    df_sel['age_groupall'] = 1
    df_sel['age_group1'] = df_sel['age'].apply(lambda x: 1 if x < 60 else 0)
    df_sel['age_group2'] = df_sel['age'].apply(lambda x: 1 if x >= 60 and x < 70 else 0)
    df_sel['age_group3'] = df_sel['age'].apply(lambda x: 1 if x >= 70 else 0)
    print(df_sel[['age_group1', 'age_group2', 'age_group3']].sum())
# Out:
# ___
# dt_group1    244
# dt_group2    155
# dt_group3    224
# dtype: int64
# age_group1    285
# age_group2    187
# age_group3    151
# dtype: int64
# ___
# dt_group1    75
# dt_group2    44
# dt_group3    41
# dtype: int64
# age_group1    48
# age_group2    51
# age_group3    61
# dtype: int64

# %%
from decimal import Decimal

def hypothesis_prepare_sleep_mri(df_hypothesis_sleep, df_hypothesis_mri, df_covariates):
    df_hypothesis = pd.concat([df_hypothesis_sleep, df_hypothesis_mri, df_covariates], axis=1)
    print(f"N = {len(df_hypothesis)}")
    pairs = list(product(df_hypothesis_sleep.columns, df_hypothesis_mri.columns))
    
    return pairs

def hypothesis_test_routine_pairs(df, pairs, results=None):
    
    for statistical_test in ['pearsonr', 'partial_pearsonr']:
        print(f'\n{statistical_test.upper()}')
        for pair in pairs:
            # df_pair = df_hypothesis[[pair[0], pair[1], 'age', 'sex']].dropna(how='any', axis=0)
            df_pair = df[[pair[0], pair[1], 'age', 'sex']].dropna(how='any', axis=0)
            x = df_pair.iloc[:, 0]
            y = df_pair.iloc[:, 1]
            # z-standardize x and y for stability:
            x = (x - x.mean()) / x.std()
            y = (y - y.mean()) / y.std()
            age_sel = df_pair.iloc[:, 2]
            sex_sel = df_pair.iloc[:, 3]
            t, p = do_correlation(x, y, statistical_test, age_sel, sex_sel)
            print(f"{pair}, N={len(df_pair)}: {np.round(t, 3)}, {Decimal(p):.2E}")
            if results is not None:
                results.loc[str(pair), f'r {statistical_test}'] = t
                results.loc[str(pair), f'p {statistical_test}'] = p
    return results

def do_correlation(x, y, test, age_sel, sex_sel):

    if test == 'pearsonr':
        test_statistic, p_val = pearsonr(x, y)
    elif test == 'partial_pearsonr':
        df_partial = pd.DataFrame(np.array([x, y, age_sel, sex_sel]).T, columns=['x', 'y', 'age', 'sex'])
        stats = partial_corr(df_partial, x='x', y='y', covar=['age', 'sex'],  method='pearson') # , 'sex'
        test_statistic = stats['r'].item()
        p_val = stats['p-val'].item()
        
    return test_statistic, p_val


def hypothesis_prepare_cognition(df_hypothesis_sleep, df_hypothesis_mri):
    # print(f"N = {len(df_hypothesis_sleep)}")
    pairs = list(product(df_hypothesis_sleep.columns, ['mmse'])) + list(product(df_hypothesis_mri.columns, ['mmse']))
    
    return pairs

# %%
def run_analysis_for_selected_cohort(df_sel):
    """
    df_sel: selected cohort
    returns results dataframe
    """

    ### covariates
    age = df_sel.age.values
    sex = df_sel.sex.astype(int) # convert male/female to 1/0
    df_covariates = pd.DataFrame(np.array([age, sex]).T, columns=['age', 'sex'])
    df_covariates.index = df_sel.index
    assert all(df_sel.index == df_covariates.index)

    # print(f"N = {len(df_sel)}")

    results = pd.DataFrame()

    hypothesis_name = 'slow waves'
    df_hypothesis_sleep, df_hypothesis_mri = get_hypothesis_data(df_sel, df_sel, hypothesis_name)
    pairs = hypothesis_prepare_sleep_mri(df_hypothesis_sleep, df_hypothesis_mri, df_covariates)
    results = hypothesis_test_routine_pairs(df_sel, pairs, results)

    hypothesis_name = 'spindles'
    df_hypothesis_sleep, df_hypothesis_mri = get_hypothesis_data(df_sel, df_sel, hypothesis_name)
    pairs = hypothesis_prepare_sleep_mri(df_hypothesis_sleep, df_hypothesis_mri, df_covariates)
    results = hypothesis_test_routine_pairs(df_sel, pairs, results)

    hypothesis_name = 'rem'
    df_hypothesis_sleep, df_hypothesis_mri = get_hypothesis_data(df_sel, df_sel, hypothesis_name)
    pairs = hypothesis_prepare_sleep_mri(df_hypothesis_sleep, df_hypothesis_mri, df_covariates)
    results = hypothesis_test_routine_pairs(df_sel, pairs, results)

    hypothesis_name = 'wake'
    df_hypothesis_sleep, df_hypothesis_mri = get_hypothesis_data(df_sel, df_sel, hypothesis_name)
    pairs = hypothesis_prepare_sleep_mri(df_hypothesis_sleep, df_hypothesis_mri, df_covariates)
    results = hypothesis_test_routine_pairs(df_sel, pairs, results)

    for hypothesis_name in ['slow waves', 'spindles', 'rem', 'wake']:
        df_hypothesis_sleep, df_hypothesis_mri = get_hypothesis_data(df_sel, df_sel, hypothesis_name)
        df_hypothesis_sleep = df_hypothesis_sleep.loc[df_sel.index]
        df_hypothesis_mri = df_hypothesis_mri.loc[df_sel.index]
        df_covariates = df_covariates.loc[df_sel.index]
        
        pairs = hypothesis_prepare_cognition(df_hypothesis_sleep, df_hypothesis_mri)
        results = hypothesis_test_routine_pairs(df_sel, pairs, results)

    # add N, age statistic and sex statistic in results
    results['N'] = [len(df_sel)] * len(results)
    results['age statistic'] = [f"{np.round(df_sel['age'].mean(), 1)} ({np.round(df_sel['age'].std(), 1)})"] * len(results)
    results['% female'] = [f"{(np.round(1- df_sel['sex'].mean(), 2))}"] * len(results)

    # for all the cognition pairs, add N and age statistic
    results.loc[results.index.str.contains('mmse'), 'N'] = str(df_sel.mmse.notna().sum())
    results.loc[results.index.str.contains('mmse'), 'age statistic'] = f"{np.round(df_sel['age'].loc[df_sel.mmse.notna()].mean(), 1)} ({np.round(df_sel['age'].loc[df_sel.mmse.notna()].std(), 1)})"
    results.loc[results.index.str.contains('mmse'), '% female'] = f"{(np.round(1- df_sel.loc[df_sel.mmse.notna(), 'sex'].mean(), 2))}"

    print(results.head(2))

    return results

# %%
results_collection = {}

# restrict df_sel to the intersection of dt and age groups:

for dt_sel in ['dt_groupall', 'dt_group1', 'dt_group2', 'dt_group3']:
    for age_sel in ['age_groupall', 'age_group1', 'age_group2', 'age_group3']:
        df_sel = df_all[(df_all[dt_sel] == 1) & (df_all[age_sel] == 1)]

        namestr = f"{group_names[dt_sel]}, {group_names[age_sel]}"
        print(f"\n{dt_sel}, {age_sel}")

        results = run_analysis_for_selected_cohort(df_sel)
        results.to_csv(f'./results/results_hypotheses_{namestr}.csv', index_label='pair')
        results_collection[namestr] = results


# make reuslts_collection a dataframe with multiindex.
df_multiindex = pd.concat(results_collection, axis=0, names=['group', 'feature_pair'])
feature_pairs_all = list(df_multiindex.xs(key='dt all, age all', level='group').index)
# Out:
# dt_groupall, age_groupall
# N = 623
#
# PEARSONR
# ('slowdelta_bandpower_total', 'vol-ctx--anterior'), N=623: 0.1, 1.26E-2
# ('slowdelta_bandpower_total', 'vol-thalamus'), N=623: 0.271, 5.54E-12
# ('so_rate_f', 'vol-ctx--anterior'), N=623: 0.083, 3.72E-2
# ('so_rate_f', 'vol-thalamus'), N=623: 0.2, 4.97E-7
#
# PARTIAL_PEARSONR
# ('slowdelta_bandpower_total', 'vol-ctx--anterior'), N=623: -0.043, 2.79E-1
# ('slowdelta_bandpower_total', 'vol-thalamus'), N=623: -0.013, 7.53E-1
# ('so_rate_f', 'vol-ctx--anterior'), N=623: -0.014, 7.23E-1
# ('so_rate_f', 'vol-thalamus'), N=623: -0.002, 9.54E-1
# N = 623
#
# PEARSONR
# ('ss_dens_f', 'vol-thalamus'), N=623: 0.194, 1.01E-6
# ('ss_dens_f', 'vol-hippocampus'), N=623: 0.079, 4.91E-2
# ('fs_dens_c', 'vol-thalamus'), N=623: 0.312, 1.71E-15
# ('fs_dens_c', 'vol-hippocampus'), N=623: 0.174, 1.19E-5
#
# PARTIAL_PEARSONR
# ('ss_dens_f', 'vol-thalamus'), N=623: 0.006, 8.77E-1
# ('ss_dens_f', 'vol-hippocampus'), N=623: -0.017, 6.69E-1
# ('fs_dens_c', 'vol-thalamus'), N=623: 0.11, 6.06E-3
# ('fs_dens_c', 'vol-hippocampus'), N=623: 0.064, 1.10E-1
# N = 623
#
# PEARSONR
# ('perc_r', 'vol-ctx--isthmuscingulate'), N=623: 0.013, 7.44E-1
# ('perc_r', 'vol-amygdala'), N=623: 0.024, 5.53E-1
# ('perc_r', 'vol-brain-stem'), N=623: 0.022, 5.75E-1
#
# PARTIAL_PEARSONR
# ('perc_r', 'vol-ctx--isthmuscingulate'), N=623: 0.006, 8.85E-1
# ('perc_r', 'vol-amygdala'), N=623: -0.015, 7.08E-1
# ('perc_r', 'vol-brain-stem'), N=623: 0.024, 5.52E-1
# N = 623
#
# PEARSONR
# ('alpha_bandpower_mean_o_w', 'vol-thalamus'), N=623: 0.014, 7.29E-1
# ('alpha_bandpower_mean_o_w', 'vol-total_ventricle'), N=623: -0.037, 3.63E-1
#
# PARTIAL_PEARSONR
# ('alpha_bandpower_mean_o_w', 'vol-thalamus'), N=623: 0.01, 8.13E-1
# ('alpha_bandpower_mean_o_w', 'vol-total_ventricle'), N=623: -0.04, 3.21E-1
#
# PEARSONR
# ('slowdelta_bandpower_total', 'mmse'), N=160: -0.014, 8.56E-1
# ('so_rate_f', 'mmse'), N=160: -0.031, 6.98E-1
# ('vol-ctx--anterior', 'mmse'), N=160: 0.03, 7.05E-1
# ('vol-thalamus', 'mmse'), N=160: 0.206, 8.96E-3
#
# PARTIAL_PEARSONR
# ('slowdelta_bandpower_total', 'mmse'), N=160: -0.091, 2.57E-1
# ('so_rate_f', 'mmse'), N=160: -0.089, 2.65E-1
# ('vol-ctx--anterior', 'mmse'), N=160: -0.042, 5.98E-1
# ('vol-thalamus', 'mmse'), N=160: 0.063, 4.30E-1
#
# PEARSONR
# ('ss_dens_f', 'mmse'), N=160: 0.175, 2.69E-2
# ('fs_dens_c', 'mmse'), N=160: 0.204, 9.76E-3
# ('vol-thalamus', 'mmse'), N=160: 0.206, 8.96E-3
# ('vol-hippocampus', 'mmse'), N=160: 0.196, 1.29E-2
#
# PARTIAL_PEARSONR
# ('ss_dens_f', 'mmse'), N=160: 0.103, 1.96E-1
# ('fs_dens_c', 'mmse'), N=160: 0.102, 2.02E-1
# ('vol-thalamus', 'mmse'), N=160: 0.063, 4.30E-1
# ('vol-hippocampus', 'mmse'), N=160: 0.116, 1.45E-1
#
# PEARSONR
# ('perc_r', 'mmse'), N=160: 0.174, 2.78E-2
# ('vol-ctx--isthmuscingulate', 'mmse'), N=160: 0.057, 4.78E-1
# ('vol-amygdala', 'mmse'), N=160: 0.294, 1.63E-4
# ('vol-brain-stem', 'mmse'), N=160: 0.031, 6.94E-1
#
# PARTIAL_PEARSONR
# ('perc_r', 'mmse'), N=160: 0.164, 3.93E-2
# ('vol-ctx--isthmuscingulate', 'mmse'), N=160: 0.078, 3.29E-1
# ('vol-amygdala', 'mmse'), N=160: 0.204, 1.01E-2
# ('vol-brain-stem', 'mmse'), N=160: 0.028, 7.25E-1
#
# PEARSONR
# ('alpha_bandpower_mean_o_w', 'mmse'), N=160: 0.083, 2.97E-1
# ('vol-thalamus', 'mmse'), N=160: 0.206, 8.96E-3
# ('vol-total_ventricle', 'mmse'), N=160: -0.244, 1.89E-3
#
# PARTIAL_PEARSONR
# ('alpha_bandpower_mean_o_w', 'mmse'), N=160: 0.083, 3.00E-1
# ('vol-thalamus', 'mmse'), N=160: 0.063, 4.30E-1
# ('vol-total_ventricle', 'mmse'), N=160: -0.147, 6.61E-2
#                                                     r pearsonr    p pearsonr  \
# ('slowdelta_bandpower_total', 'vol-ctx--anterior')    0.099891  1.261336e-02
# ('slowdelta_bandpower_total', 'vol-thalamus')         0.271429  5.539088e-12
#
#                                                     r partial_pearsonr  \
# ('slowdelta_bandpower_total', 'vol-ctx--anterior')           -0.043495
# ('slowdelta_bandpower_total', 'vol-thalamus')                -0.012671
#
#                                                     p partial_pearsonr    N  \
# ('slowdelta_bandpower_total', 'vol-ctx--anterior')            0.279159  623
# ('slowdelta_bandpower_total', 'vol-thalamus')                 0.752656  623
#
#                                                    age statistic % female
# ('slowdelta_bandpower_total', 'vol-ctx--anterior')   60.9 (12.5)     0.55
# ('slowdelta_bandpower_total', 'vol-thalamus')        60.9 (12.5)     0.55
#
# dt_groupall, age_group1
# N = 285
#
# PEARSONR
# ('slowdelta_bandpower_total', 'vol-ctx--anterior'), N=285: -0.015, 8.01E-1
# ('slowdelta_bandpower_total', 'vol-thalamus'), N=285: 0.145, 1.46E-2
# ('so_rate_f', 'vol-ctx--anterior'), N=285: -0.011, 8.49E-1
# ('so_rate_f', 'vol-thalamus'), N=285: 0.106, 7.51E-2
#
# PARTIAL_PEARSONR
# ('slowdelta_bandpower_total', 'vol-ctx--anterior'), N=285: -0.084, 1.60E-1
# ('slowdelta_bandpower_total', 'vol-thalamus'), N
#
# PEARSONR
# ('slowdelta_bandpower_total', 'vol-ctx--anterior'), N=187: 0.0, 9.96E-1
# ('slowdelta_bandpower_total', 'vol-thalamus'), N=187: 0.163, 2.54E-2
# /tmp/ipykernel_3391179/2773539133.py:53: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '160' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   results.loc[results.index.str.contains('mmse'), 'N'] = str(df_sel.mmse.notna().sum())
# /tmp/ipykernel_3391179/2773539133.py:53: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '48' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   results.loc[results.index.str.contains('mmse'), 'N'] = str(df_sel.mmse.notna().sum())
# ('so_rate_f', 'vol-ctx--anterior'), N=187: 0.08, 2.75E-1
# ('so_rate_f', 'vol-thalamus'), N=187: 0.131, 7.34E-2
#
# PARTIAL_PEARSONR
# ('slowdelta_bandpower_total', 'vol-ctx--anterior'), N=187: 0.028, 7.06E-1
# ('slowdelta_bandpower_total', 'vol-thalamus'), N=187: 0.1, 1.77E-1
# ('so_rate_f', 'vol-ctx--anterior'), N=187: 0.096, 1.91E-1
# ('so_rate_f', 'vol-thalamus'), N=187: 0.068, 3.60E-1
# N = 187
#
# PEARSONR
# ('ss_dens_f', 'vol-thalamus'), N=187: 0.098, 1.84E-1
# ('ss_dens_f', 'vol-hippocampus'), N=187: 0.004, 9.57E-1
# ('fs_dens_c', 'vol-thalamus'), N=187: 0.285, 7.76E-5
# ('fs_dens_c', 'vol-hippocampus'), N=187: 0.114, 1.21E-1
#
# PARTIAL_PEARSONR
# ('ss_dens_f', 'vol-thalamus'), N=187: 0.056, 4.51E-1
# ('ss_dens_f', 'vol-hippocampus'), N=187: -0.027, 7.10E-1
# ('fs_dens_c', 'vol-thalamus'), N=187: 0.277, 1.32E-4
# ('fs_dens_c', 'vol-hippocampus'), N=187: 0.103, 1.61E-1
# N = 187
#
# PEARSONR
# ('perc_r', 'vol-ctx--isthmuscingulate'), N=187: 0.006, 9.32E-1
# ('perc_r', 'vol-amygdala'), N=187: 0.051, 4.88E-1
# ('perc_r', 'vol-brain-stem'), N=187: 0.136, 6.25E-2
#
# PARTIAL_PEARSONR
# ('perc_r', 'vol-ctx--isthmuscingulate'), N=187: 0.0, 9.95E-1
# ('perc_r', 'vol-amygdala'), N=187: 0.044, 5.51E-1
# ('perc_r', 'vol-brain-stem'), N=187: 0.156, 3.41E-2
# N = 187
#
# PEARSONR
# ('alpha_bandpower_mean_o_w', 'vol-thalamus'), N=187: 0.027, 7.12E-1
# ('alpha_bandpower_mean_o_w', 'vol-total_ventricle'), N=187: -0.09, 2.21E-1
#
# PARTIAL_PEARSONR
# ('alpha_bandpower_mean_o_w', 'vol-thalamus'), N=187: -0.005, 9.48E-1
# ('alpha_bandpower_mean_o_w', 'vol-total_ventricle'), N=187: -0.069, 3.51E-1
#
# PEARSONR
# ('slowdelta_bandpower_total', 'mmse'), N=51: -0.174, 2.21E-1
# ('so_rate_f', 'mmse'), N=51: -0.105, 4.63E-1
# ('vol-ctx--anterior', 'mmse'), N=51: -0.084, 5.56E-1
# ('vol-thalamus', 'mmse'), N=51: -0.01, 9.43E-1
#
# PARTIAL_PEARSONR
# ('slowdelta_bandpower_total', 'mmse'), N=51: -0.139, 3.39E-1
# ('so_rate_f', 'mmse'), N=51: -0.06, 6.84E-1
# ('vol-ctx--anterior', 'mmse'), N=51: -0.106, 4.69E-1
# ('vol-thalamus', 'mmse'), N=51: 0.001, 9.97E-1
#
# PEARSONR
# ('ss_dens_f', 'mmse'), N=51: 0.269, 5.65E-2
# ('fs_dens_c', 'mmse'), N=51: 0.113, 4.29E-1
# ('vol-thalamus', 'mmse'), N=51: -0.01, 9.43E-1
# ('vol-hippocampus', 'mmse'), N=51: -0.005, 9.75E-1
#
# PARTIAL_PEARSONR
# ('ss_dens_f', 'mmse'), N=51: 0.296, 3.92E-2
# ('fs_dens_c', 'mmse'), N=51: 0.115, 4.30E-1
# ('vol-thalamus', 'mmse'), N=51: 0.001, 9.97E-1
# ('vol-hippocampus', 'mmse'), N=51: 0.028, 8.47E-1
#
# PEARSONR
# ('perc_r', 'mmse'), N=51: 0.212, 1.36E-1
# ('vol-ctx--isthmuscingulate', 'mmse'), N=51: 0.183, 2.00E-1
# ('vol-amygdala', 'mmse'), N=51: 0.175, 2.20E-1
# ('vol-brain-stem', 'mmse'), N=51: 0.088, 5.41E-1
#
# PARTIAL_PEARSONR
# ('perc_r', 'mmse'), N=51: 0.185, 2.03E-1
# ('vol-ctx--isthmuscingulate', 'mmse'), N=51: 0.165, 2.57E-1
# ('vol-amygdala', 'mmse'), N=51: 0.188, 1.95E-1
# ('vol-brain-stem', 'mmse'), N=51: 0.097, 5.07E-1
#
# PEARSONR
# ('alpha_bandpower_mean_o_w', 'mmse'), N=51: 0.16, 2.61E-1
# ('vol-thalamus', 'mmse'), N=51: -0.01, 9.43E-1
# ('vol-total_ventricle', 'mmse'), N=51: -0.205, 1.49E-1
#
# PARTIAL_PEARSONR
# ('alpha_bandpower_mean_o_w', 'mmse'), N
-1
#
# PARTIAL_PEARSONR
# ('ss_dens_f', 'mmse'), N=21: -0.13, 5.97E-1
# ('fs_dens_c', 'mmse'), N=21: 0.258, 2.87E-1
# ('vol-thalamus', 'mmse'), N=21: 0.135, 5.81E-1
# ('vol-hippocampus', 'mmse'), N=21: -0.068, 7.81E-1
#
# PEARSONR
# ('perc_r', 'mmse'), N=21: 0.236, 3.04E-1
# ('vol-ctx--isthmuscingulate', 'mmse'), N=21: 0.108, 6.41E-1
# ('vol-amygdala', 'mmse'), N=21: 0.002, 9.92E-1
# ('vol-brain-stem', 'mmse'), N=21: -0.253, 2.69E-1
#
# PARTIAL_PEARSONR
# /tmp/ipykernel_3391179/2773539133.py:53: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '75' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   results.loc[results.index.str.contains('mmse'), 'N'] = str(df_sel.mmse.notna().sum())
# /tmp/ipykernel_3391179/2773539133.py:53: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '21' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   results.loc[results.index.str.contains('mmse'), 'N'] = str(df_sel.mmse.notna().sum())
# ('perc_r', 'mmse'), N=21: 0.206, 3.98E-1
# ('vol-ctx--isthmuscingulate', 'mmse'), N=21: 0.121, 6.23E-1
# ('vol-amygdala', 'mmse'), N=21: 0.024, 9.21E-1
# ('vol-brain-stem', 'mmse'), N=21: -0.271, 2.62E-1
#
# PEARSONR
# ('alpha_bandpower_mean_o_w', 'mmse'), N=21: 0.07, 7.63E-1
# ('vol-thalamus', 'mmse'), N=21: 0.012, 9.58E-1
# ('vol-total_ventricle', 'mmse'), N=21: -0.083, 7.22E-1
#
# PARTIAL_PEARSONR
# ('alpha_bandpower_mean_o_w', 'mmse'), N=21: 0.132, 5.90E-1
# ('vol-thalamus', 'mmse'), N=21: 0.135, 5.81E-1
# ('vol-total_ventricle', 'mmse'), N=21: -0.175, 4.73E-1
#                                                     r pearsonr  p pearsonr  \
# ('slowdelta_bandpower_total', 'vol-ctx--anterior')   -0.157810    0.096552
# ('slowdelta_bandpower_total', 'vol-thalamus')         0.074264    0.436453
#
#                                                     r partial_pearsonr  \
# ('slowdelta_bandpower_total', 'vol-ctx--anterior')           -0.175566
# ('slowdelta_bandpower_total', 'vol-thalamus')                -0.027250
#
#                                                     p partial_pearsonr    N  \
# ('slowdelta_bandpower_total', 'vol-ctx--anterior')            0.066567  112
# ('slowdelta_bandpower_total', 'vol-thalamus')                 0.777489  112
#
#                                                    age statistic % female
# ('slowdelta_bandpower_total', 'vol-ctx--anterior')    49.4 (7.4)     0.62
# ('slowdelta_bandpower_total', 'vol-thalamus')         49.4 (7.4)     0.62
#
# dt_group1, age_group2
# N = 72
#
# PEARSONR
# ('slowdelta_bandpower_total', 'vol-ctx--anterior'), N=72: 0.028, 8.15E-1
# ('slowdelta_bandpower_total', 'vol-thalamus'), N=72: 0.208, 8.00E-2
# ('so_rate_f', 'vol-ctx--anterior'), N=72: 0.167, 1.60E-1
# ('so_rate_f', 'vol-thalamus'), N=72: 0.113, 3.44E-1
#
# PARTIAL_PEARSONR
# ('slowdelta_bandpower_total', 'vol-ctx--anterior'), N=72: 0.094, 4.40E-1
# ('slowdelta_bandpower_total', 'vol-thalamus'), N=72: 0.155, 2.02E-1
# ('so_rate_f', 'vol-ctx--anterior'), N=72: 0.191, 1.14E-1
# ('so_rate_f', 'vol-thalamus'), N=72: 0.024, 8.41E-1
# N = 72
#
# PEARSONR
# ('ss_dens_f', 'vol-thalamus'), N=72: 0.042, 7.23E-1
# ('ss_dens_f', 'vol-hippocampus'), N=72: 0.127, 2.89E-1
# ('fs_dens_c', 'vol-thalamus'), N=72: 0.27, 2.20E-2
# ('fs_dens_c', 'vol-hippocampus'), N=72: 0.208, 7.95E-2
#
# PARTIAL_PEARSONR
# ('ss_dens_f', 'vol-thalamus'), N=72: -0.004, 9.75E-1
# ('ss_dens_f', 'vol-hippocampus'), N=72: 0.101, 4.06E-1
# ('fs_dens_c', 'vol-thalamus'), N=72: 0.237, 4.78E-2
# ('fs_dens_c', 'vol-hippocampus'), N=72: 0.181, 1.34E-1
# N = 72
#
# PEARSONR
# ('perc_r', 'vol-ctx--isthmuscingulate'), N=72: -0.04, 7.41E-1
# ('perc_r', 'vol-amygdala'), N=72: 0.113, 3.46E-1
# ('perc_r', 'vol-brain-stem'), N=72: 0.176, 1.39E-1
#
# PARTIAL_PEARSONR
# ('perc_r', 'vol-ctx--isthmuscingulate'), N=72: -0.053, 6.66E-1
# ('perc_r', 'vol-amygdala'), N=72: 0.131, 2.79E-1
# ('perc_r', 'vol-brain-stem'), N=72: 0.203, 9.25E-2
# N = 72
#
# PEARSONR
# ('alpha_bandpower_mean_o_w', 'vol-thalamus'), N=72: 0.039, 7.42E-1
# ('alpha_bandpower_mean_o_w', 'vol-total_ventricle'), N=72: -0.118, 3.22E-1
#
# PARTIAL_PEARSONR
# ('alpha_bandpower_mean_o_w', 'vol-thalamus'), N=72: -0.032, 7.91E-1
# ('alpha_bandpower_mean_o_w', 'vol-total_ventricle'), N=72: -0.076, 5.32E-1
#
# PEARSONR
# ('slowdelta_bandpower_total', 'mmse'), N=23: -0.583, 3.49E-3
# ('so_rate_f', 'mmse'), N=23: -0.398, 6.03E-2
# ('vol-ctx--anterior', 'mmse'), N=23: -0.241, 2.68E-1
# ('vol-thalamus', 'mmse'), N=23: -0.227, 2.98E-1
#
# PARTIAL_PEARSONR
# ('slowdelta_bandpower_total', 'mmse'), N=23: -0.588, 5.10E-3
# ('so_rate_f', 'mmse'), N=23: -0.355, 1.14E-1
# ('vol-ctx--anterior', 'mmse'), N=23: -0.333, 1.40E-1
# ('vol-thalamus', 'mmse'), N=23: -0.306, 1.77E-1
#
# PEARSONR
# ('ss_dens_f', 'mmse'), N=23: 0.184, 4.01E-1
# ('fs_dens_c', 'mmse'), N=23: -0.082, 7.10E-1
# ('vol-thalamus', 'mmse'), N=23: -0.227, 2.98E-1
# ('vol-hippocampus', 'mmse'), N=23: -0.271, 2.11E-1
#
# PARTIAL_PEARSONR
# ('ss_dens_f', 'mmse'), N=23: 0.194, 4.00E-1
# ('fs_dens_c', 'mmse'), N=23: -0.031, 8.92E-1
# ('vol-thalamus', 'mmse'), N=23: -0.306, 1.77E-1
# ('vol-hippocampus', 'mmse'), N=23: -0.297, 1.92E-1
#
# PEARSONR
# ('perc_r', 'mmse'), N=23: 0.069, 7.54E-1
# ('vol-ctx--isthmuscingulate', 'mmse'), N=23: 0.043, 8.45E-1
# ('vol-amygdala', 'mmse'), N=23: 0.022, 9.20E-1
# ('vol-brain-stem', 'mmse'), N=23: -0.198, 3.66E-1
#
# PARTIAL_PEARSONR
# ('perc_r', 'mmse'), N=23: 0.044, 8.48E-1
# ('vol-ctx--isthmuscingulate', 'mmse'), N=23: 0.014, 9.54E-1
# ('vol-amygdala', 'mmse'), N=23: -0.007, 9.77E-1
# ('vol-brain-stem', 'mmse'), N=23: -0.213, 3.53E-1
#
# PEARSONR
# ('alpha_bandpower_mean_o_w', 'mmse'), N=23: 0.247, 2.56E-1
# ('vol-thalamus', 'mmse'), N=23: -0.227, 2.98E-1
# ('vol-total_ventricle', 'mmse'), N=23: -0.1, 6.49E-1
#
# PARTIAL_PEARSONR
# ('alpha_bandpower_mean_o_w', 'mmse'), N=23: 0.249, 2.77E-1
# ('vol-thalamus', 'mmse'), N=23: -0.306, 1.77E-1
# ('vol-total_ventricle', 'mmse'), N=23: -0.064, 7.83E-1
#                                                     r pearsonr  p pearsonr  \
# ('slowdelta_bandpower_total', 'vol-ctx--anterior')    0.028050    0.815066
# ('slowdelta_bandpower_total', 'vol-thalamus')         0.207713    0.079979
#
#                                                     r partial_pearsonr  \
# ('slowdelta_bandpower_total', 'vol-ctx--anterior')            0.093840
# ('slowdelta_bandpower_total', 'vol-thalamus')                 0.154512
#
#                                                     p partial_pearsonr   N  \
# ('slowdelta_bandpower_total', 'vol-ctx--anterior')            0.439703  72
# ('slowdelta_bandpower_total', 'vol-thalamus')                 0.201549  72
#
#                                                    age statistic % female
# ('slowdelta_bandpower_total', 'vol-ctx--anterior')    65.2 (2.9)     0.57
# ('slowdelta_bandpower_total', 'vol-thalamus')         65.2 (2.9)     0.57
#
# dt_group1, age_group3
# N = 60
#
# PEARSONR
# ('slowdelta_bandpower_total', 'vol-ctx--anterior'), N=60: 0.117, 3.74E-1
# ('slowdelta_bandpower_total', 'vol-thalamus'), N=60: 0.133, 3.11E-1
# ('so_rate_f', 'vol-ctx--anterior'), N=60: -0.008, 9.51E-1
# ('so_rate_f', 'vol-thalamus'), N=60: 0.066, 6.17E-1
#
# PARTIAL_PEARSONR
# ('slowdelta_bandpower_total', 'vol-ctx--anterior'), N=60: 0.104, 4.39E-1
# ('slowdelta_bandpower_total', 'vol-thalamus'), N=60: -0.043, 7.48E-1
# ('so_rate_f', 'vol-ctx--anterior'), N=60: 0.009, 9.44E-1
# ('so_rate_f', 'vol-thalamus'), N=60: -0.04, 7.65E-1
# N = 60
#
# PEARSONR
# ('ss_dens_f', 'vol-thalamus'), N=60: 0.155, 2.38E-1
# ('ss_dens_f', 'vol-hippocampus'), N=60: 0.101, 4.43E-1
# ('fs_dens_c', 'vol-thalamus'), N=60: 0.153, 2.43E-1
# ('fs_dens_c', 'vol-hippocampus'), N=60: 0.105, 4.24E-1
#
# PARTIAL_PEARSONR
# ('ss_dens_f', 'vol-thalamus'), N=60: 0.121, 3.66E-1
# ('ss_dens_f', 'vol-hippocampus'), N=60: 0.02, 8.81E-1
# ('fs_dens_c', 'vol-thalamus'), N=60: 0.023, 8.67E-1
# ('fs_dens_c', 'vol-hippocampus'), N=60: -0.03, 8.23E-1
# N = 60
#
# PEARSONR
# ('perc_r', 'vol-ctx--isthmuscingulate'), N=60: 0.004, 9.78E-1
# ('perc_r', 'vol-amygdala'), N=60: 0.07, 5.94E-1
# ('perc_r', 'vol-brain-stem'), N=60: 0.285, 2.72E-2
#
# PARTIAL_PEARSONR
# ('perc_r', 'vol-ctx--isthmuscingulate'), N=60: -0.001, 9.92E-1
# ('perc_r', 'vol-amygdala'), N=60: 0.061, 6.47E-1
# ('perc_r', 'vol-brain-stem'), N=60: 0.301, 2.17E-2
# N = 60
#
# PEARSONR
# ('alpha_bandpower_mean_o_w', 'vol-thalamus'), N=60: 0.092, 4.84E-1
# ('alpha_bandpower_mean_o_w', 'vol-total_ventricle'), N=60: -0.046, 7.27E-1
#
# PARTIAL_PEARSONR
# ('alpha_bandpower_mean_o_w', 'vol-thalamus'), N=60: 0.045, 7.40E-1
# ('alpha_bandpower_mean_o_w', 'vol-total_ventricle'), N=60: -0.01, 9.42E-1
#
# PEARSONR
# ('slowdelta_bandpower_total', 'mmse'), N=31: 0.025, 8.93E-1
# ('so_rate_f', 'mmse'), N=31: -0.008, 9.65E-1
# ('vol-ctx--anterior', 'mmse'), N=31: 0.152, 4.13E-1
# ('vol-thalamus', 'mmse'), N=31: 0.294, 1.08E-1
#
# PARTIAL_PEARSONR
# ('slowdelta_bandpower_total', 'mmse'), N=31: 0.023, 9.08E-1
# ('so_rate_f', 'mmse'), N=31: -0.015, 9.39E-1
# ('vol-ctx--anterior', 'mmse'), N=31: 0.041, 8.32E-1
# ('vol-thalamus', 'mmse'), N=31: 0.242, 2.06E-1
#
# PEARSONR
# ('ss_dens_f', 'mmse'), N
#
# PEARSONR
# ('perc_r', 'vol-ctx--isthmuscingulate'), N=50: 0.087, 5.46E-1
# ('perc_r', 'vol-amygdala'), N=50: 0.138, 3.40E-1
# ('perc_r', 'vol-brain-stem'), N=50: 0.371, 7.93E-3
#
# PARTIAL_PEARSONR
# ('perc_r', 'vol-ctx--isthmuscingulate'), N=50: 0.132, 3.73E-1
# ('perc_r', 'vol-amygdala'), N=50: 0.115, 4.35E-1
# ('perc_r', 'vol-brain-stem'), N=50: 0.422, 2.85E-3
# N = 50
#
# PEARSONR
# ('alpha_bandpower_mean_o_w', 'vol-thalamus'), N=50: 0.045, 7.54E-1
# ('alpha_bandpower_mean_o_w', 'vol-total_ventricle'), N=50: -0.061, 6.76E-1
#
# PARTIAL_PEARSONR
# ('alpha_bandpower_mean_o_w', 'vol-thalamus'), N=50: 0.02, 8.90E-1
# ('alpha_bandpower_mean_o_w', 'vol-total_ventricle'), N=50: -0.046, 7.54E-1
#
# PEARSONR
# ('slowdelta_bandpower_total', 'mmse'), N=15: 0.053, 8.51E-1
# ('so_rate_f', 'mmse'), N=15: 0.099, 7.24E-1
# ('vol-ctx--anterior', 'mmse'), N=15: -0.023, 9.35E-1
# ...
# ('fs_dens_c', 'mmse'), N=41: -0.044, 7.92E-1
# ('vol-thalamus', 'mmse'), N=41: 0.147, 3.73E-1
# ('vol-hippocampus', 'mmse'), N=41: 0.191, 2.45E-1
#
# PEARSONR
# ('perc_r', 'mmse'), N=41: 0.308, 4.99E-2
# ('vol-ctx--isthmuscingulate', 'mmse'), N=41: 0.027, 8.67E-1
# ('vol-amygdala', 'mmse'), N=41: 0.423, 5.92E-3
# ('vol-brain-stem', 'mmse'), N=41: 0.001, 9.97E-1
#
# PARTIAL_PEARSONR
# ('perc_r', 'mmse'), N=41: 0.238, 1.45E-1
# ('vol-ctx--isthmuscingulate', 'mmse'), N=41: 0.175, 2.88E-1
# ('vol-amygdala', 'mmse'), N=41: 0.379, 1.75E-2
# ('vol-brain-stem', 'mmse'), N=41: 0.07, 6.73E-1
#
# PEARSONR
# ('alpha_bandpower_mean_o_w', 'mmse'), N=41: -0.013, 9.35E-1
# ('vol-thalamus', 'mmse'), N=41: 0.251, 1.14E-1
# ('vol-total_ventricle', 'mmse'), N=41: -0.235, 1.40E-1
#
# PARTIAL_PEARSONR
# ('alpha_bandpower_mean_o_w', 'mmse'), N=41: 0.042, 8.02E-1
# ('vol-thalamus', 'mmse'), N=41: 0.147, 3.73E-1
# ('vol-total_ventricle', 'mmse'), N=41: -0.165, 3.14E-1
#                                                     r pearsonr  p pearsonr  \
# ('slowdelta_bandpower_total', 'vol-ctx--anterior')    0.153880    0.021227
# ('slowdelta_bandpower_total', 'vol-thalamus')         0.277882    0.000025
#
#                                                     r partial_pearsonr  \
# ('slowdelta_bandpower_total', 'vol-ctx--anterior')           -0.002905
# ('slowdelta_bandpower_total', 'vol-thalamus')                 0.011433
#
#                                                     p partial_pearsonr    N  \
# ('slowdelta_bandpower_total', 'vol-ctx--anterior')            0.965671  224
# ('slowdelta_bandpower_total', 'vol-thalamus')                 0.865483  224
#
#                                                    age statistic % female
# ('slowdelta_bandpower_total', 'vol-ctx--anterior')   60.2 (12.8)     0.58
# ('slowdelta_bandpower_total', 'vol-thalamus')        60.2 (12.8)     0.58
#
# dt_group3, age_group1
# N = 107
#
# PEARSONR
# ('slowdelta_bandpower_total', 'vol-ctx--anterior'), N=107: 0.035, 7.23E-1
# ('slowdelta_bandpower_total', 'vol-thalamus'), N=107: 0.178, 6.65E-2
# ('so_rate_f', 'vol-ctx--anterior'), N=107: -0.005, 9.61E-1
# ('so_rate_f', 'vol-thalamus'), N=107: 0.158, 1.04E-1
#
# PARTIAL_PEARSONR
# ('slowdelta_bandpower_total', 'vol-ctx--anterior'), N=107: -0.057, 5.67E-1
# ('slowdelta_bandpower_total', 'vol-thalamus'), N=107: -0.045, 6.52E-1
# ('so_rate_f', 'vol-ctx--anterior'), N=107: -0.095, 3.34E-1
# ('so_rate_f', 'vol-thalamus'), N=107: -0.012, 9.05E-1
# N = 107
#
# PEARSONR
# ('ss_dens_f', 'vol-thalamus'), N=107: -0.054, 5.79E-1
# ('ss_dens_f', 'vol-hippocampus'), N=107: 0.045, 6.44E-1
# ('fs_dens_c', 'vol-thalamus'), N=107: 0.186, 5.50E-2
# ('fs_dens_c', 'vol-hippocampus'), N=107: 0.183, 5.88E-2
#
# PARTIAL_PEARSONR
# ('ss_dens_f', 'vol-thalamus'), N=107: -0.049, 6.17E-1
# ('ss_dens_f', 'vol-hippocampus'), N=107: 0.042, 6.67E-1
# ('fs_dens_c', 'vol-thalamus'), N=107: 0.069, 4.86E-1
# ('fs_dens_c', 'vol-hippocampus'), N=107: 0.128, 1.92E-1
# N = 107
#
# PEARSONR
# ('perc_r', 'vol-ctx--isthmuscingulate'), N=107: -0.063, 5.18E-1
# ('perc_r', 'vol-amygdala'), N=107: 0.002, 9.87E-1
# ('perc_r', 'vol-brain-stem'), N=107: 0.05, 6.08E-1
#
# PARTIAL_PEARSONR
# /tmp/ipykernel_3391179/2773539133.py:53: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '41' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   results.loc[results.index.str.contains('mmse'), 'N'] = str(df_sel.mmse.notna().sum())
# /tmp/ipykernel_3391179/2773539133.py:53: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '12' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   results.loc[results.index.str.contains('mmse'), 'N'] = str(df_sel.mmse.notna().sum())
# ('perc_r', 'vol-ctx--isthmuscingulate'), N=107: -0.064, 5.17E-1
# ('perc_r', 'vol-amygdala'), N=107: 0.004, 9.69E-1
# ('perc_r', 'vol-brain-stem'), N=107: 0.066, 5.02E-1
# N = 107
#
# PEARSONR
# ('alpha_bandpower_mean_o_w', 'vol-thalamus'), N=107: 0.085, 3.86E-1
# ('alpha_bandpower_mean_o_w', 'vol-total_ventricle'), N
-1
#
# PARTIAL_PEARSONR
# ('perc_r', 'vol-ctx--isthmuscingulate'), N=65: -0.069, 5.89E-1
# ('perc_r', 'vol-amygdala'), N=65: -0.149, 2.43E-1
# ('perc_r', 'vol-brain-stem'), N=65: -0.186, 1.45E-1
# N = 65
#
# PEARSONR
# ('alpha_bandpower_mean_o_w', 'vol-thalamus'), N=65: 0.024, 8.47E-1
# ('alpha_bandpower_mean_o_w', 'vol-total_ventricle'), N=65: -0.142, 2.60E-1
#
# PARTIAL_PEARSONR
# ('alpha_bandpower_mean_o_w', 'vol-thalamus'), N=65: 0.023, 8.55E-1
# ('alpha_bandpower_mean_o_w', 'vol-total_ventricle'), N=65: -0.149, 2.44E-1
#
# PEARSONR
# ('slowdelta_bandpower_total', 'mmse'), N=13: -0.118, 7.00E-1
# ('so_rate_f', 'mmse'), N=13: -0.113, 7.12E-1
# ('vol-ctx--anterior', 'mmse'), N=13: -0.019, 9.50E-1
# ('vol-thalamus', 'mmse'), N=13: 0.346, 2.47E-1
#
# PARTIAL_PEARSONR
# ('slowdelta_bandpower_total', 'mmse'), N=13: -0.094, 7.84E-1
# ('so_rate_f', 'mmse'), N=13: -0.099, 7.73E-1
# ('vol-ctx--anterior', 'mmse'), N=13: 0.075, 8.26E-1
# ('vol-thalamus', 'mmse'), N=13: 0.52, 1.01E-1
#
# PEARSONR
# ('ss_dens_f', 'mmse'), N=13: -0.049, 8.75E-1
# ('fs_dens_c', 'mmse'), N=13: -0.067, 8.27E-1
# ('vol-thalamus', 'mmse'), N=13: 0.346, 2.47E-1
# ('vol-hippocampus', 'mmse'), N=13: 0.117, 7.04E-1
#
# PARTIAL_PEARSONR
# ('ss_dens_f', 'mmse'), N=13: 0.156, 6.48E-1
# ('fs_dens_c', 'mmse'), N=13: -0.158, 6.42E-1
# ('vol-thalamus', 'mmse'), N=13: 0.52, 1.01E-1
# ('vol-hippocampus', 'mmse'), N=13: 0.246, 4.65E-1
#
# PEARSONR
# ('perc_r', 'mmse'), N=13: 0.083, 7.88E-1
# ('vol-ctx--isthmuscingulate', 'mmse'), N=13: 0.155, 6.14E-1
# ('vol-amygdala', 'mmse'), N=13: 0.231, 4.47E-1
# ('vol-brain-stem', 'mmse'), N=13: 0.258, 3.94E-1
#
# PARTIAL_PEARSONR
# ('perc_r', 'mmse'), N=13: -0.153, 6.53E-1
# ('vol-ctx--isthmuscingulate', 'mmse'), N=13: 0.084, 8.05E-1
# ('vol-amygdala', 'mmse'), N=13: 0.584, 5.92E-2
# ('vol-brain-stem', 'mmse'), N=13: 0.428, 1.89E-1
#
# PEARSONR
# ('alpha_bandpower_mean_o_w', 'mmse'), N=13: -0.249, 4.13E-1
# ('vol-thalamus', 'mmse'), N=13: 0.346, 2.47E-1
# ('vol-total_ventricle', 'mmse'), N=13: -0.383, 1.96E-1
#
# PARTIAL_PEARSONR
# ('alpha_bandpower_mean_o_w', 'mmse'), N=13: -0.256, 4.47E-1
# ('vol-thalamus', 'mmse'), N=13: 0.52, 1.01E-1
# ('vol-total_ventricle', 'mmse'), N=13: -0.483, 1.33E-1
#                                                     r pearsonr  p pearsonr  \
# ('slowdelta_bandpower_total', 'vol-ctx--anterior')    0.152047    0.226625
# ('slowdelta_bandpower_total', 'vol-thalamus')         0.162557    0.195745
#
#                                                     r partial_pearsonr  \
# ('slowdelta_bandpower_total', 'vol-ctx--anterior')            0.142145
# ('slowdelta_bandpower_total', 'vol-thalamus')                 0.144656
#
#                                                     p partial_pearsonr   N  \
# ('slowdelta_bandpower_total', 'vol-ctx--anterior')            0.266440  65
# ('slowdelta_bandpower_total', 'vol-thalamus')                 0.257996  65
#
#                                                    age statistic % female
# ('slowdelta_bandpower_total', 'vol-ctx--anterior')    64.8 (2.8)     0.62
# ('slowdelta_bandpower_total', 'vol-thalamus')         64.8 (2.8)     0.62
#
# dt_group3, age_group3
# N = 52
#
# PEARSONR
# ('slowdelta_bandpower_total', 'vol-ctx--anterior'), N=52: 0.006, 9.68E-1
# ('slowdelta_bandpower_total', 'vol-thalamus'), N=52: 0.093, 5.10E-1
# ('so_rate_f', 'vol-ctx--anterior'), N=52: -0.039, 7.83E-1
# ('so_rate_f', 'vol-thalamus'), N=52: 0.15, 2.90E-1
#
# PARTIAL_PEARSONR
# ('slowdelta_bandpower_total', 'vol-ctx--anterior'), N=52: 0.024, 8.70E-1
# ('slowdelta_bandpower_total', 'vol-thalamus'), N=52: -0.024, 8.67E-1
# ('so_rate_f', 'vol-ctx--anterior'), N=52: -0.021, 8.83E-1
# ('so_rate_f', 'vol-thalamus'), N=52: 0.071, 6.22E-1
# N = 52
#
# PEARSONR
# ('ss_dens_f', 'vol-thalamus'), N=52: 0.25, 7.42E-2
# ('ss_dens_f', 'vol-hippocampus'), N=52: 0.096, 5.00E-1
# ('fs_dens_c', 'vol-thalamus'), N=52: 0.209, 1.36E-1
# ('fs_dens_c', 'vol-hippocampus'), N=52: 0.19, 1.77E-1
#
# PARTIAL_PEARSONR
# ('ss_dens_f', 'vol-thalamus'), N=52: 0.176, 2.21E-1
# ('ss_dens_f', 'vol-hippocampus'), N=52: 0.087, 5.47E-1
# ('fs_dens_c', 'vol-thalamus'), N=52: 0.246, 8.53E-2
# ('fs_dens_c', 'vol-hippocampus'), N=52: 0.199, 1.67E-1
# N = 52
#
# PEARSONR
# ('perc_r', 'vol-ctx--isthmuscingulate'), N=52: 0.017, 9.07E-1
# ('perc_r', 'vol-amygdala'), N=52: 0.058, 6.83E-1
# ('perc_r', 'vol-brain-stem'), N=52: 0.091, 5.21E-1
#
# PARTIAL_PEARSONR
# ('perc_r', 'vol-ctx--isthmuscingulate'), N=52: -0.0, 9.97E-1
# ('perc_r', 'vol-amygdala'), N=52: 0.068, 6.38E-1
# ('perc_r', 'vol-brain-stem'), N=52: 0.141, 3.27E-1
# N = 52
#
# PEARSONR
# ('alpha_bandpower_mean_o_w', 'vol-thalamus'), N=52: 0.0, 1.00E+0
# ('alpha_bandpower_mean_o_w', 'vol-total_ventricle'), N=52: 0.119, 3.99E-1
#
# PARTIAL_PEARSONR
# ('alpha_bandpower_mean_o_w', 'vol-thalamus'), N=52: -0.088, 5.42E-1
# ('alpha_bandpower_mean_o_w', 'vol-total_ventricle'), N=52: 0.198, 1.69E-1
#
# PEARSONR
# ('slowdelta_bandpower_total', 'mmse'), N=16: -0.748, 8.69E-4
# ('so_rate_f', 'mmse'), N=16: -0.631, 8.79E-3
# ('vol-ctx--anterior', 'mmse'), N=16: -0.18, 5.05E-1
# ('vol-thalamus', 'mmse'), N=16: 0.05, 8.53E-1
#
# PARTIAL_PEARSONR
# ('slowdelta_bandpower_total', 'mmse'), N=16: -0.834, 2.11E-4
# ('so_rate_f', 'mmse'), N=16: -0.665, 9.50E-3
# ('vol-ctx--anterior', 'mmse'), N=16: -0.143, 6.25E-1
# ('vol-thalamus', 'mmse'), N=16: 0.118, 6.88E-1
#
# PEARSONR
# ('ss_dens_f', 'mmse'), N=16: 0.3, 2.59E-1
# ('fs_dens_c', 'mmse'), N=16: 0.185, 4.94E-1
# ('vol-thalamus', 'mmse'), N=16: 0.05, 8.53E-1
# ('vol-hippocampus', 'mmse'), N=16: 0.241, 3.68E-1
#
# PARTIAL_PEARSONR
# ('ss_dens_f', 'mmse'), N=16: 0.365, 2.00E-1
# ('fs_dens_c', 'mmse'), N=16: 0.207, 4.78E-1
# ('vol-thalamus', 'mmse'), N=16: 0.118, 6.88E-1
# ('vol-hippocampus', 'mmse'), N=16: 0.308, 2.84E-1
#
# PEARSONR
# ('perc_r', 'mmse'), N=16: 0.509, 4.42E-2
# ('vol-ctx--isthmuscingulate', 'mmse'), N=16: 0.135, 6.19E-1
# ('vol-amygdala', 'mmse'), N=16: 0.44, 8.77E-2
# ('vol-brain-stem', 'mmse'), N=16: -0.006, 9.83E-1
#
# PARTIAL_PEARSONR
# ('perc_r', 'mmse'), N=16: 0.558, 3.80E-2
# ('vol-ctx--isthmuscingulate', 'mmse'), N=16: 0.253, 3.82E-1
# ('vol-amygdala', 'mmse'), N=16: 0.523, 5.49E-2
# ('vol-brain-stem', 'mmse'), N=16: 0.005, 9.88E-1
#
# PEARSONR
# ('alpha_bandpower_mean_o_w', 'mmse'), N=16: 0.033, 9.04E-1
# ('vol-thalamus', 'mmse'), N=16: 0.05, 8.53E-1
# ('vol-total_ventricle', 'mmse'), N=16: 0.067, 8.05E-1
#
# PARTIAL_PEARSONR
# ('alpha_bandpower_mean_o_w', 'mmse'), N=16: 0.082, 7.82E-1
# ('vol-thalamus', 'mmse'), N=16: 0.118, 6.88E-1
# ('vol-total_ventricle', 'mmse'), N=16: -0.004, 9.89E-1
#                                                     r pearsonr  p pearsonr  \
# ('slowdelta_bandpower_total', 'vol-ctx--anterior')    0.005645    0.968316
# ('slowdelta_bandpower_total', 'vol-thalamus')         0.093398    0.510172
#
#                                                     r partial_pearsonr  \
# ('slowdelta_bandpower_total', 'vol-ctx--anterior')            0.023748
# ('slowdelta_bandpower_total', 'vol-thalamus')                -0.024266
#
#                                                     p partial_pearsonr   N  \
# ('slowdelta_bandpower_total', 'vol-ctx--anterior')            0.869967  52
# ('slowdelta_bandpower_total', 'vol-thalamus')                 0.867158  52
#
#                                                    age statistic % female
# ('slowdelta_bandpower_total', 'vol-ctx--anterior')    76.3 (4.7)     0.42
# ('slowdelta_bandpower_total', 'vol-thalamus')         76.3 (4.7)     0.42
# /tmp/ipykernel_3391179/2773539133.py:53: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '13' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   results.loc[results.index.str.contains('mmse'), 'N'] = str(df_sel.mmse.notna().sum())
# /tmp/ipykernel_3391179/2773539133.py:53: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '16' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   results.loc[results.index.str.contains('mmse'), 'N'] = str(df_sel.mmse.notna().sum())

# %%
results.head()
# Out:
#                                                     r pearsonr  p pearsonr  \
# ('slowdelta_bandpower_total', 'vol-ctx--anterior')    0.005645    0.968316
# ('slowdelta_bandpower_total', 'vol-thalamus')         0.093398    0.510172
# ('so_rate_f', 'vol-ctx--anterior')                   -0.039077    0.783280
# ('so_rate_f', 'vol-thalamus')                         0.149646    0.289663
# ('ss_dens_f', 'vol-thalamus')                         0.249759    0.074152
#
#                                                     r partial_pearsonr  \
# ('slowdelta_bandpower_total', 'vol-ctx--anterior')            0.023748
# ('slowdelta_bandpower_total', 'vol-thalamus')                -0.024266
# ('so_rate_f', 'vol-ctx--anterior')                           -0.021372
# ('so_rate_f', 'vol-thalamus')                                 0.071410
# ('ss_dens_f', 'vol-thalamus')                                 0.176189
#
#                                                     p partial_pearsonr   N  \
# ('slowdelta_bandpower_total', 'vol-ctx--anterior')            0.869967  52
# ('slowdelta_bandpower_total', 'vol-thalamus')                 0.867158  52
# ('so_rate_f', 'vol-ctx--anterior')                            0.882879  52
# ('so_rate_f', 'vol-thalamus')                                 0.622150  52
# ('ss_dens_f', 'vol-thalamus')                                 0.220977  52
#
#                                                    age statistic % female
# ('slowdelta_bandpower_total', 'vol-ctx--anterior')    76.3 (4.7)     0.42
# ('slowdelta_bandpower_total', 'vol-thalamus')         76.3 (4.7)     0.42
# ('so_rate_f', 'vol-ctx--anterior')                    76.3 (4.7)     0.42
# ('so_rate_f', 'vol-thalamus')                         76.3 (4.7)     0.42
# ('ss_dens_f', 'vol-thalamus')                         76.3 (4.7)     0.42

# %%
feature_pair = str(('slowdelta_bandpower_total', 'vol-ctx--anterior'))

df_feature_pair = df_multiindex.xs(key=feature_pair, level='feature_pair').copy()
df_feature_pair.index.name = feature_pair
# check how many of the "p partial_pearsonr" are significant:
df_feature_pair.loc['percentage significant', 'p partial_pearsonr'] = np.round(df_feature_pair['p partial_pearsonr'].apply(lambda x: float(x) < 0.05).sum() / len(df_feature_pair), 2)
df_feature_pair
# Out:
#                                                     r pearsonr  p pearsonr  \
# ('slowdelta_bandpower_total', 'vol-ctx--anterior')
# dt all, age all                                       0.099891    0.012613
# dt all, age younger than 60                          -0.014984    0.801148
# dt all, age between 60-70                             0.000342    0.996291
# dt all, age older than 70                             0.076077    0.353186
# dt within 1 year, age all                             0.020060    0.755211
# dt within 1 year, age younger than 60                -0.157810    0.096552
# dt within 1 year, age between 60-70                   0.028050    0.815066
# dt within 1 year, age older than 70                   0.116848    0.373941
# dt between 1-2.5 years, age all                       0.124520    0.122653
# dt between 1-2.5 years, age younger than 60           0.273256    0.026421
# dt between 1-2.5 years, age between 60-70            -0.346253    0.013771
# dt between 1-2.5 years, age older than 70             0.086285    0.601467
# dt between 2.5-7 years, age all                       0.153880    0.021227
# dt between 2.5-7 years, age younger than 60           0.034695    0.722753
# dt between 2.5-7 years, age between 60-70             0.152047    0.226625
# dt between 2.5-7 years, age older than 70             0.005645    0.968316
# percentage significant                                     NaN         NaN
#
#                                                     r partial_pearsonr  \
# ('slowdelta_bandpower_total', 'vol-ctx--anterior')
# dt all, age all                                              -0.043495
# dt all, age younger than 60                                  -0.083690
# dt all, age between 60-70                                     0.027963
# dt all, age older than 70                                     0.059654
# dt within 1 year, age all                                    -0.093007
# dt within 1 year, age younger than 60                        -0.175566
# dt within 1 year, age between 60-70                           0.093840
# dt within 1 year, age older than 70                           0.103567
# dt between 1-2.5 years, age all                              -0.011931
# dt between 1-2.5 years, age younger than 60                   0.198934
# dt between 1-2.5 years, age between 60-70                    -0.279236
# dt between 1-2.5 years, age older than 70                     0.001816
# dt between 2.5-7 years, age all                              -0.002905
# dt between 2.5-7 years, age younger than 60                  -0.056503
# dt between 2.5-7 years, age between 60-70                     0.142145
# dt between 2.5-7 years, age older than 70                     0.023748
# percentage significant                                             NaN
#
#                                                     p partial_pearsonr    N  \
# ('slowdelta_bandpower_total', 'vol-ctx--anterior')
# dt all, age all                                               0.279159  623
# dt all, age younger than 60                                   0.160284  285
# dt all, age between 60-70                                     0.705553  187
# dt all, age older than 70                                     0.469877  151
# dt within 1 year, age all                                     0.149166  244
# dt within 1 year, age younger than 60                         0.066567  112
# dt within 1 year, age between 60-70                           0.439703   72
# dt within 1 year, age older than 70                           0.439135   60
# dt between 1-2.5 years, age all                               0.883629  155
# dt between 1-2.5 years, age younger than 60                   0.115049   66
# dt between 1-2.5 years, age between 60-70                     0.054602   50
# dt between 1-2.5 years, age older than 70                     0.991487   39
# dt between 2.5-7 years, age all                               0.965671  224
# dt between 2.5-7 years, age younger than 60                   0.566975  107
# dt between 2.5-7 years, age between 60-70                     0.266440   65
# dt between 2.5-7 years, age older than 70                     0.869967   52
# percentage significant                                        0.000000  NaN
#
#                                                    age statistic % female
# ('slowdelta_bandpower_total', 'vol-ctx--anterior')
# dt all, age all                                      60.9 (12.5)     0.55
# dt all, age younger than 60                           49.9 (7.9)     0.61
# dt all, age between 60-70                             65.1 (2.9)     0.58
# dt all, age older than 70                             76.6 (4.6)     0.39
# dt within 1 year, age all                            60.8 (12.8)     0.57
# dt within 1 year, age younger than 60                 49.4 (7.4)     0.62
# dt within 1 year, age between 60-70                   65.2 (2.9)     0.57
# dt within 1 year, age older than 70                   76.9 (4.8)     0.45
# dt between 1-2.5 years, age all                      62.1 (11.6)     0.47
# dt between 1-2.5 years, age younger than 60           51.2 (7.2)     0.55
# dt between 1-2.5 years, age between 60-70             65.1 (2.9)     0.54
# dt between 1-2.5 years, age older than 70             76.5 (4.1)     0.26
# dt between 2.5-7 years, age all                      60.2 (12.8)     0.58
# dt between 2.5-7 years, age younger than 60           49.6 (8.7)     0.64
# dt between 2.5-7 years, age between 60-70             64.8 (2.8)     0.62
# dt between 2.5-7 years, age older than 70             76.3 (4.7)     0.42
# percentage significant                                       NaN      NaN

# %%
df_multiindex.xs(key='dt all, age all', level='group').head(3)
# Out:
#                                                     r pearsonr    p pearsonr  \
# feature_pair
# ('slowdelta_bandpower_total', 'vol-ctx--anterior')    0.099891  1.261336e-02
# ('slowdelta_bandpower_total', 'vol-thalamus')         0.271429  5.539088e-12
# ('so_rate_f', 'vol-ctx--anterior')                    0.083479  3.724356e-02
#
#                                                     r partial_pearsonr  \
# feature_pair
# ('slowdelta_bandpower_total', 'vol-ctx--anterior')           -0.043495
# ('slowdelta_bandpower_total', 'vol-thalamus')                -0.012671
# ('so_rate_f', 'vol-ctx--anterior')                           -0.014250
#
#                                                     p partial_pearsonr    N  \
# feature_pair
# ('slowdelta_bandpower_total', 'vol-ctx--anterior')            0.279159  623
# ('slowdelta_bandpower_total', 'vol-thalamus')                 0.752656  623
# ('so_rate_f', 'vol-ctx--anterior')                            0.723024  623
#
#                                                    age statistic % female
# feature_pair
# ('slowdelta_bandpower_total', 'vol-ctx--anterior')   60.9 (12.5)     0.55
# ('slowdelta_bandpower_total', 'vol-thalamus')        60.9 (12.5)     0.55
# ('so_rate_f', 'vol-ctx--anterior')                   60.9 (12.5)     0.55

# %%
feature_pairs_all
# Out:
# ["('slowdelta_bandpower_total', 'vol-ctx--anterior')",
#  "('slowdelta_bandpower_total', 'vol-thalamus')",
#  "('so_rate_f', 'vol-ctx--anterior')",
#  "('so_rate_f', 'vol-thalamus')",
#  "('ss_dens_f', 'vol-thalamus')",
#  "('ss_dens_f', 'vol-hippocampus')",
#  "('fs_dens_c', 'vol-thalamus')",
#  "('fs_dens_c', 'vol-hippocampus')",
#  "('perc_r', 'vol-ctx--isthmuscingulate')",
#  "('perc_r', 'vol-amygdala')",
#  "('perc_r', 'vol-brain-stem')",
#  "('alpha_bandpower_mean_o_w', 'vol-thalamus')",
#  "('alpha_bandpower_mean_o_w', 'vol-total_ventricle')",
#  "('slowdelta_bandpower_total', 'mmse')",
#  "('so_rate_f', 'mmse')",
#  "('vol-ctx--anterior', 'mmse')",
#  "('vol-thalamus', 'mmse')",
#  "('ss_dens_f', 'mmse')",
#  "('fs_dens_c', 'mmse')",
#  "('vol-hippocampus', 'mmse')",
#  "('perc_r', 'mmse')",
#  "('vol-ctx--isthmuscingulate', 'mmse')",
#  "('vol-amygdala', 'mmse')",
#  "('vol-brain-stem', 'mmse')",
#  "('alpha_bandpower_mean_o_w', 'mmse')",
#  "('vol-total_ventricle', 'mmse')"]

# %%
# reverse the order of the index levels:
df_multiindex = df_multiindex.swaplevel(0, 1, axis=0).loc[feature_pairs_all]
# df_multiindex = df_multiindex.sort_index(axis=0, level=0)

# add a row of NaNs when there's a change of "feature_pair"
for feature_pair in feature_pairs_all:
    df_multiindex.loc[(feature_pair, 'zzz_blank'), :] = np.nan
df_multiindex = df_multiindex.loc[feature_pairs_all]
df_multiindex.to_csv(f'./results/results_hypotheses_sensitivity.csv', index_label='pair')

# %%
df_multiindex
# Out:
#                                                                                                 r pearsonr  \
# feature_pair                                       group
# ('slowdelta_bandpower_total', 'vol-ctx--anterior') dt all, age all                                0.099891
#                                                    dt all, age younger than 60                   -0.014984
#                                                    dt all, age between 60-70                      0.000342
#                                                    dt all, age older than 70                      0.076077
#                                                    dt within 1 year, age all                      0.020060
# ...                                                                                                    ...
# ('vol-total_ventricle', 'mmse')                    dt between 2.5-7 years, age all               -0.234735
#                                                    dt between 2.5-7 years, age younger than 60   -0.514033
#                                                    dt between 2.5-7 years, age between 60-70     -0.383059
#                                                    dt between 2.5-7 years, age older than 70      0.067001
#                                                    zzz_blank                                           NaN
#
#                                                                                                 p pearsonr  \
# feature_pair                                       group
# ('slowdelta_bandpower_total', 'vol-ctx--anterior') dt all, age all                                0.012613
#                                                    dt all, age younger than 60                    0.801148
#                                                    dt all, age between 60-70                      0.996291
#                                                    dt all, age older than 70                      0.353186
#                                                    dt within 1 year, age all                      0.755211
# ...                                                                                                    ...
# ('vol-total_ventricle', 'mmse')                    dt between 2.5-7 years, age all                0.139599
#                                                    dt between 2.5-7 years, age younger than 60    0.087333
#                                                    dt between 2.5-7 years, age between 60-70      0.196378
#                                                    dt between 2.5-7 years, age older than 70      0.805263
#                                                    zzz_blank                                           NaN
#
#                                                                                                 r partial_pearsonr  \
# feature_pair                                       group
# ('slowdelta_bandpower_total', 'vol-ctx--anterior') dt all, age all                                       -0.043495
#                                                    dt all, age younger than 60                           -0.083690
#                                                    dt all, age between 60-70                              0.027963
#                                                    dt all, age older than 70                              0.059654
#                                                    dt within 1 year, age all                             -0.093007
# ...                                                                                                            ...
# ('vol-total_ventricle', 'mmse')                    dt between 2.5-7 years, age all                       -0.165474
#                                                    dt between 2.5-7 years, age younger than 60           -0.451228
#                                                    dt between 2.5-7 years, age between 60-70             -0.482803
#                                                    dt between 2.5-7 years, age older than 70             -0.004093
#                                                    zzz_blank                                                   NaN
#
#                                                                                                 p partial_pearsonr  \
# feature_pair                                       group
# ('slowdelta_bandpower_total', 'vol-ctx--anterior') dt all, age all                                        0.279159
#                                                    dt all, age younger than 60                            0.160284
#                                                    dt all, age between 60-70                              0.705553
#                                                    dt all, age older than 70                              0.469877
#                                                    dt within 1 year, age all                              0.149166
# ...                                                                                                            ...
# ('vol-total_ventricle', 'mmse')                    dt between 2.5-7 years, age all                        0.314066
#                                                    dt between 2.5-7 years, age younger than 60            0.190550
#                                                    dt between 2.5-7 years, age between 60-70              0.132527
#                                                    dt between 2.5-7 years, age older than 70              0.988922
#                                                    zzz_blank                                                   NaN
#
#                                                                                                   N  \
# feature_pair                                       group
# ('slowdelta_bandpower_total', 'vol-ctx--anterior') dt all, age all                              623
#                                                    dt all, age younger than 60                  285
#                                                    dt all, age between 60-70                    187
#                                                    dt all, age older than 70                    151
#                                                    dt within 1 year, age all                    244
# ...                                                                                             ...
# ('vol-total_ventricle', 'mmse')                    dt between 2.5-7 years, age all               41
#                                                    dt between 2.5-7 years, age younger than 60   12
#                                                    dt between 2.5-7 years, age between 60-70     13
#                                                    dt between 2.5-7 years, age older than 70     16
#                                                    zzz_blank                                    NaN
#
#                                                                                                age statistic  \
# feature_pair                                       group
# ('slowdelta_bandpower_total', 'vol-ctx--anterior') dt all, age all                               60.9 (12.5)
#                                                    dt all, age younger than 60                    49.9 (7.9)
#                                                    dt all, age between 60-70                      65.1 (2.9)
#                                                    dt all, age older than 70                      76.6 (4.6)
#                                                    dt within 1 year, age all                     60.8 (12.8)
# ...                                                                                                      ...
# ('vol-total_ventricle', 'mmse')                    dt between 2.5-7 years, age all               65.8 (10.5)
#                                                    dt between 2.5-7 years, age younger than 60    52.7 (5.7)
#                                                    dt between 2.5-7 years, age between 60-70      65.5 (2.4)
#                                                    dt between 2.5-7 years, age older than 70      75.9 (4.7)
#                                                    zzz_blank                                             NaN
#
#                                                                                                % female
# feature_pair                                       group
# ('slowdelta_bandpower_total', 'vol-ctx--anterior') dt all, age all                                 0.55
#                                                    dt all, age younger than 60                     0.61
#                                                    dt all, age between 60-70                       0.58
#                                                    dt all, age older than 70                       0.39
#                                                    dt within 1 year, age all                       0.57
# ...                                                                                                 ...
# ('vol-total_ventricle', 'mmse')                    dt between 2.5-7 years, age all                 0.44
#                                                    dt between 2.5-7 years, age younger than 60     0.58
#                                                    dt between 2.5-7 years, age between 60-70       0.54
#                                                    dt between 2.5-7 years, age older than 70       0.25
#                                                    zzz_blank                                        NaN
#
# [442 rows x 7 columns]

# %% [raw]
# ### also do the stratification by disease group:
#
#
# given MCI/dementia diagnosis may have largest effect on the brain, how about removing those from any other disease group?
# top 5 disease groups (table 1):
# -- Dementia
# -- MCI
# -- Depression without Dementia or MCI
# -- Cancer
# -- Diabetes with or without complications
# -- CHF
# -- Peripheral vascular disease
# -- cerebrovascular disease
#
# without dementia:
# CCI < 2
# CCI 2-4
# CCI >=5

# %%
df.index
# Out:
# Index(['sid00', 'sid01', 'sid02', 'sid03', 'sid04', 'sid05', 'sid06', 'sid07',
#        'sid08', 'sid09',
#        ...
#        'sid613', 'sid614', 'sid615', 'sid616', 'sid617', 'sid618', 'sid619',
#        'sid620', 'sid621', 'sid622'],
#       dtype='object', name='sid', length=623)

# %%
table1 = pd.read_csv(os.path.join('table1_information_deidentified.csv'), index_col=0)

assert np.isin(df.index, table1.index).all()

# %%
table1['dx_strata_cci<2'] = (table1['cci_score'] < 2).astype(int)
table1['dx_strata_cci2-4'] = ((table1['cci_score'] >= 2) & (table1['cci_score'] < 4)).astype(int)
table1['dx_strata_cci>=5'] = (table1['cci_score'] >= 5).astype(int)

# print N's
print(f"N = {len(table1)}")
print(f"N CCI<2 = {len(table1[table1['dx_strata_cci<2'] == 1])}")
print(f"N CCI 2-4 = {len(table1[table1['dx_strata_cci2-4'] == 1])}")
print(f"N CCI>=5 = {len(table1[table1['dx_strata_cci>=5'] == 1])}")

table1['dx_mci_dementia'] = table1['dx_dementia_cat'].apply(lambda x: 1 if x in ['mci', 'dementia'] else 0)
table1['dx_mci'] = table1['dx_dementia_cat'].apply(lambda x: 1 if x in ['mci'] else 0)
table1['dx_dementia'] = table1['dx_dementia_cat'].apply(lambda x: 1 if x in ['dementia'] else 0)

print(f"N MCI or dementia = {len(table1[table1['dx_mci_dementia'] == 1])}")
print(f"N MCI = {len(table1[table1['dx_mci'] == 1])}")
print(f"N dementia = {len(table1[table1['dx_dementia'] == 1])}")

disease_cats = ['dx_elix_depre', 'dx_cci_canc', 'dx_cci_diab', 'dx_cci_chf', 'dx_cci_pvd', 'dx_cci_cevd']

# make new disease categories for those diseases where people with mci or dementia are excluded:
for disease_cat in disease_cats:
    table1[f'{disease_cat}_no_mci_dementia'] = table1[disease_cat] * (1 - table1['dx_mci_dementia'])
    table1[f'{disease_cat}_no_mci'] = table1[disease_cat] * (1 - table1['dx_mci'])
    table1[f'{disease_cat}_no_dementia'] = table1[disease_cat] * (1 - table1['dx_dementia'])

    # print N's
    print(f"N {disease_cat}_no_mci_dementia = {len(table1[table1[f'{disease_cat}_no_mci_dementia'] == 1])}")

# and a category where none of the above diseases are present: # also no dementia or mci:
table1['dx_no_disease'] = table1[disease_cats + ['dx_mci_dementia']].sum(axis=1) == 0
print(f"N dx_no_disease = {len(table1[table1['dx_no_disease'] == 1])}")
# no disease and CCI < 2:
table1['dx_no_disease_cci<2'] = table1['dx_no_disease'] * table1['dx_strata_cci<2']
print(f"N dx_no_disease_cci<2 = {len(table1[table1['dx_no_disease_cci<2'] == 1])}")
# Out:
# N = 623
# N CCI<2 = 240
# N CCI 2-4 = 201
# N CCI>=5 = 82
# N MCI or dementia = 107
# N MCI = 71
# N dementia = 36
# N dx_elix_depre_no_mci_dementia = 262
# N dx_cci_canc_no_mci_dementia = 127
# N dx_cci_diab_no_mci_dementia = 120
# N dx_cci_chf_no_mci_dementia = 78
# N dx_cci_pvd_no_mci_dementia = 87
# N dx_cci_cevd_no_mci_dementia = 136
# N dx_no_disease = 131
# N dx_no_disease_cci<2 = 86

# %%
def rename(df_multiindex):

    # Create a list to store the modified levels
    new_levels = []

    # Loop through each level in the MultiIndex
    for level in df_multiindex.index.levels:
        # Apply the string replacement operation and append to new_levels
        new_levels.append(level.astype(str).str.replace('dx_strata_cci', 'CCI'))
        new_levels.append(level.astype(str).str.replace('dx_no_disease', 'No disease'))
        new_levels.append(level.astype(str).str.replace('dx_no_disease_cci<2', 'No disease, CCI<2'))
        new_levels.append(level.astype(str).str.replace('dx_elix_depre', 'Depression'))
        new_levels.append(level.astype(str).str.replace('dx_cci_canc', 'Cancer'))
        new_levels.append(level.astype(str).str.replace('dx_cci_diab', 'Diabetes'))
        new_levels.append(level.astype(str).str.replace('dx_cci_chf', 'Congestive heart failure'))
        new_levels.append(level.astype(str).str.replace('dx_cci_pvd', 'Peripheral vascular disease'))
        new_levels.append(level.astype(str).str.replace('dx_cci_cevd', 'Cerebrovascular disease'))
        new_levels.append(level.astype(str).str.replace('dx_mci', 'MCI'))
        new_levels.append(level.astype(str).str.replace('dx_dementia', 'Dementia'))

        new_levels.append(level.astype(str).str.replace('slowdelta_bandpower_total', 'Total slow and delta power'))
        new_levels.append(level.astype(str).str.replace('so_rate_f', 'SO rate frontal'))
        new_levels.append(level.astype(str).str.replace('ss_dens_f', 'Slow spindles density frontal'))
        new_levels.append(level.astype(str).str.replace('fs_dens_c', 'Fast spindles density central'))
        new_levels.append(level.astype(str).str.replace('perc_r', 'Percentage R'))
        new_levels.append(level.astype(str).str.replace('alpha_bandpower_mean_o_w', 'Mean alpha during W'))
        new_levels.append(level.astype(str).str.replace('vol-ctx--anterior', 'Anterior cortex'))
        new_levels.append(level.astype(str).str.replace('vol-thalamus', 'Thalamus'))
        new_levels.append(level.astype(str).str.replace('vol-hippocampus', 'Hippocampus'))
        new_levels.append(level.astype(str).str.replace('vol-amygdala', 'Amygdala'))
        new_levels.append(level.astype(str).str.replace('vol-brain-stem', 'Brainstem'))
        new_levels.append(level.astype(str).str.replace('vol-ctx--isthmuscingulate', 'Isthmuscingulate'))
        new_levels.append(level.astype(str).str.replace('vol-total_ventricle', 'Total ventricle volume'))
        new_levels.append(level.astype(str).str.replace('mmse', 'MMSE'))

    # Reconstruct the MultiIndex using the modified levels
    df_multiindex.index = pd.MultiIndex.from_arrays(new_levels, names=['group', 'feature_pair'])

    return df_multiindex

# %%
# SAME CODE AS ABOVE BUT FOR DISEASE GROUPS

disease_cats = ['dx_dementia', 'dx_mci']
disease_cats += [x + '_no_mci_dementia' for x in ['dx_elix_depre', 'dx_cci_canc', 'dx_cci_diab', 'dx_cci_chf', 'dx_cci_pvd', 'dx_cci_cevd']]
disease_cats += ['dx_strata_cci<2', 'dx_strata_cci2-4', 'dx_strata_cci>=5']
disease_cats += ['dx_no_disease', 'dx_no_disease_cci<2']

# add those disease categories to the df_all:
for disease_cat in disease_cats:
    df_all[disease_cat] = table1[disease_cat].loc[df_all.index]

results_collection = {}

# restrict df_sel to the intersection of dt and age groups:

for disease_cat in disease_cats:
    df_sel = df_all[df_all[disease_cat] == 1]

    namestr = disease_cat

    results = run_analysis_for_selected_cohort(df_sel)
    results.to_csv(f'./results/results_hypotheses_{namestr}.csv', index_label='pair')
    results_collection[namestr] = results

# make reuslts_collection a dataframe with multiindex.
df_multiindex = pd.concat(results_collection, axis=0, names=['group', 'feature_pair'])
feature_pairs_all = list(df_multiindex.xs(key='dx_mci', level='group').index)

# reverse the order of the index levels:
df_multiindex = df_multiindex.swaplevel(0, 1, axis=0).loc[feature_pairs_all]
df_multiindex = df_multiindex.sort_index(axis=0, level=0)
# sort the feature_pair value according to the disease_cats list:
df_multiindex = df_multiindex.reindex(disease_cats, level=1)

# add a row of NaNs when there's a change of "feature_pair"
for feature_pair in feature_pairs_all:
    df_multiindex.loc[(feature_pair, 'zzz_blank'), :] = np.nan
df_multiindex = df_multiindex.loc[feature_pairs_all]

# df_multiindex = rename(df_multiindex)

df_multiindex.to_csv(f'./results/results_hypotheses_sensitivity_diseases.csv', index_label='pair')
# Out:
# N = 36
#
# PEARSONR
# ('slowdelta_bandpower_total', 'vol-ctx--anterior'), N=36: 0.311, 6.50E-2
# ('slowdelta_bandpower_total', 'vol-thalamus'), N=36: 0.343, 4.03E-2
# ('so_rate_f', 'vol-ctx--anterior'), N=36: 0.134, 4.34E-1
# ('so_rate_f', 'vol-thalamus'), N=36: 0.158, 3.57E-1
#
# PARTIAL_PEARSONR
# ('slowdelta_bandpower_total', 'vol-ctx--anterior'), N=36: 0.268, 1.25E-1
# ('slowdelta_bandpower_total', 'vol-thalamus'), N=36: 0.063, 7.23E-1
# ('so_rate_f', 'vol-ctx--anterior'), N=36: 0.128, 4.70E-1
# ('so_rate_f', 'vol-thalamus'), N=36: -0.078, 6.59E-1
# N = 36
#
# PEARSONR
# ('ss_dens_f', 'vol-thalamus'), N=36: 0.361, 3.05E-2
# ('ss_dens_f', 'vol-hippocampus'), N=36: 0.32, 5.69E-2
# ('fs_dens_c', 'vol-thalamus'), N=36: 0.238, 1.61E-1
# ('fs_dens_c', 'vol-hippocampus'), N=36: 0.25, 1.41E-1
#
# PARTIAL_PEARSONR
# ('ss_dens_f', 'vol-thalamus'), N
#
# PARTIAL_PEARSONR
# ('slowdelta_bandpower_total', 'vol-ctx--anterior'), N=262: -0.039, 5.35E-1
# ('slowdelta_bandpower_total', 'vol-thalamus'), N=262: 0.046, 4.64E-1
# ('so_rate_f', 'vol-ctx--anterior'), N=262: -0.001, 9.82E-1
# ('so_rate_f', 'vol-thalamus'), N=262: 0.061, 3.25E-1
# N = 262
#
# PEARSONR
# ('ss_dens_f', 'vol-thalamus'), N=262: 0.136, 2.80E-2
# ('ss_dens_f', 'vol-hippocampus'), N=262: 0.018, 7.77E-1
# ('fs_dens_c', 'vol-thalamus'), N=262: 0.319, 1.29E-7
# ('fs_dens_c', 'vol-hippocampus'), N=262: 0.118, 5.62E-2
#
# PARTIAL_PEARSONR
# /tmp/ipykernel_3391179/2773539133.py:53: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '23' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   results.loc[results.index.str.contains('mmse'), 'N'] = str(df_sel.mmse.notna().sum())
# /tmp/ipykernel_3391179/2773539133.py:53: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '55' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   results.loc[results.index.str.contains('mmse'), 'N'] = str(df_sel.mmse.notna().sum())
# ('ss_dens_f', 'vol-thalamus'), N=262: -0.029, 6.41E-1
# ('ss_dens_f', 'vol-hippocampus'), N=262: -0.054, 3.84E-1
# ('fs_dens_c', 'vol-thalamus'), N=262: 0.117, 5.90E-2
# ('fs_dens_c', 'vol-hippocampus'), N=262: 0.025, 6.88E-1
# N = 262
#
# PEARSONR
# ('perc_r', 'vol-ctx--isthmuscingulate'), N=262: 0.116, 6.17E-2
# ('perc_r', 'vol-amygdala'), N=262: 0.014, 8.24E-1
# ('perc_r', 'vol-brain-stem'), N=262: -0.049, 4.27E-1
#
# PARTIAL_PEARSONR
# ('perc_r', 'vol-ctx--isthmuscingulate'), N=262: 0.109, 7.86E-2
# ('perc_r', 'vol-amygdala'), N=262: -0.003, 9.65E-1
# ('perc_r', 'vol-brain-stem'), N=262: -0.027, 6.67E-1
# N = 262
#
# PEARSONR
# ('alpha_bandpower_mean_o_w', 'vol-thalamus'), N=262: 0.015, 8.09E-1
# ('alpha_bandpower_mean_o_w', 'vol-total_ventricle'), N=262: 0.139, 2.43E-2
#
# PARTIAL_PEARSONR
# ('alpha_bandpower_mean_o_w', 'vol-thalamus'), N=262: 0.048, 4.43E-1
# ('alpha_bandpower_mean_o_w', 'vol-total_ventricle'), N=262: 0.137, 2.71E-2
#
# PEARSONR
# ('slowdelta_bandpower_total', 'mmse'), N=54: 0.016, 9.06E-1
# ('so_rate_f', 'mmse'), N=54: 0.005, 9.71E-1
# ('vol-ctx--anterior', 'mmse'), N=54: -0.207, 1.33E-1
# ('vol-thalamus', 'mmse'), N=54: 0.138, 3.18E-1
#
# PARTIAL_PEARSONR
# ('slowdelta_bandpower_total', 'mmse'), N=54: -0.027, 8.47E-1
# ('so_rate_f', 'mmse'), N=54: -0.024, 8.66E-1
# ('vol-ctx--anterior', 'mmse'), N=54: -0.233, 9.60E-2
# ('vol-thalamus', 'mmse'), N=54: 0.14, 3.24E-1
#
# PEARSONR
# ('ss_dens_f', 'mmse'), N=54: -0.082, 5.58E-1
# ('fs_dens_c', 'mmse'), N=54: -0.075, 5.90E-1
# ('vol-thalamus', 'mmse'), N=54: 0.138, 3.18E-1
# ('vol-hippocampus', 'mmse'), N=54: -0.109, 4.35E-1
#
# PARTIAL_PEARSONR
# ('ss_dens_f', 'mmse'), N=54: -0.073, 6.06E-1
# ('fs_dens_c', 'mmse'), N=54: -0.069, 6.25E-1
# ('vol-thalamus', 'mmse'), N=54: 0.14, 3.24E-1
# ('vol-hippocampus', 'mmse'), N=54: -0.129, 3.61E-1
#
# PEARSONR
# ('perc_r', 'mmse'), N=54: 0.234, 8.89E-2
# ('vol-ctx--isthmuscingulate', 'mmse'), N=54: -0.207, 1.32E-1
# ('vol-amygdala', 'mmse'), N=54: -0.008, 9.54E-1
# ('vol-brain-stem', 'mmse'), N=54: -0.022, 8.72E-1
#
# PARTIAL_PEARSONR
# ('perc_r', 'mmse'), N=54: 0.258, 6.43E-2
# ('vol-ctx--isthmuscingulate', 'mmse'), N=54: -0.209, 1.38E-1
# ('vol-amygdala', 'mmse'), N=54: -0.018, 9.00E-1
# ('vol-brain-stem', 'mmse'), N=54: -0.072, 6.13E-1
#
# PEARSONR
# ('alpha_bandpower_mean_o_w', 'mmse'), N=54: -0.099, 4.78E-1
# ('vol-thalamus', 'mmse'), N=54: 0.138, 3.18E-1
# ('vol-total_ventricle', 'mmse'), N=54: -0.002, 9.87E-1
#
# PARTIAL_PEARSONR
# ('alpha_bandpower_mean_o_w', 'mmse'), N=54: -0.087, 5.42E-1
# ('vol-thalamus', 'mmse'), N=54: 0.14, 3.24E-1
# ('vol-total_ventricle', 'mmse'), N=54: 0.001, 9.95E-1
#                                                     r pearsonr    p pearsonr  \
# ('slowdelta_bandpower_total', 'vol-ctx--anterior')    0.079319  2.006258e-01
# ('slowdelta_bandpower_total', 'vol-thalamus')         0.297379  9.495177e-07
#
#                                                     r partial_pearsonr  \
# ('slowdelta_bandpower_total', 'vol-ctx--anterior')           -0
-1
#
# PEARSONR
# ('perc_r', 'mmse'), N=11: 0.517, 1.04E-1
# ('vol-ctx--isthmuscingulate', 'mmse'), N=11: -0.25, 4.58E-1
# ('vol-amygdala', 'mmse'), N=11: 0.492, 1.24E-1
# ('vol-brain-stem', 'mmse'), N=11: -0.159, 6.40E-1
#
# PARTIAL_PEARSONR
# ('perc_r', 'mmse'), N=11: 0.487, 1.83E-1
# ('vol-ctx--isthmuscingulate', 'mmse'), N=11: -0.281, 4.64E-1
# ('vol-amygdala', 'mmse'), N=11: 0.434, 2.43E-1
# ('vol-brain-stem', 'mmse'), N=11: -0.03, 9.40E-1
#
# PEARSONR
# ('alpha_bandpower_mean_o_w', 'mmse'), N=11: -0.28, 4.05E-1
# ('vol-thalamus', 'mmse'), N=11: 0.272, 4.19E-1
# ('vol-total_ventricle', 'mmse'), N=11: -0.077, 8.23E-1
#
# PARTIAL_PEARSONR
# ('alpha_bandpower_mean_o_w', 'mmse'), N=11: -0.326, 3.92E-1
# ('vol-thalamus', 'mmse'), N=11: 0.185, 6.33E-1
# ('vol-total_ventricle', 'mmse'), N=11: 0.036, 9.26E-1
#                                                     r pearsonr  p pearsonr  \
# ('slowdelta_bandpower_total', 'vol-ctx--anterior')    0.106398    0.353851
# ('slowdelta_bandpower_total', 'vol-thalamus')         0.224997    0.047646
#
#                                                     r partial_pearsonr  \
# ('slowdelta_bandpower_total', 'vol-ctx--anterior')            0.032375
# ('slowdelta_bandpower_total', 'vol-thalamus')                 0.043688
#
#                                                     p partial_pearsonr   N  \
# ('slowdelta_bandpower_total', 'vol-ctx--anterior')            0.781293  78
# ('slowdelta_bandpower_total', 'vol-thalamus')                 0.707862  78
#
#                                                    age statistic % female
# ('slowdelta_bandpower_total', 'vol-ctx--anterior')   65.4 (11.1)      0.5
# ('slowdelta_bandpower_total', 'vol-thalamus')        65.4 (11.1)      0.5
# N = 87
#
# PEARSONR
# ('slowdelta_bandpower_total', 'vol-ctx--anterior'), N=87: 0.019, 8.58E-1
# ('slowdelta_bandpower_total', 'vol-thalamus'), N=87: 0.245, 2.21E-2
# ('so_rate_f', 'vol-ctx--anterior'), N=87: -0.042, 7.00E-1
# ('so_rate_f', 'vol-thalamus'), N=87: 0.157, 1.47E-1
# /tmp/ipykernel_3391179/2773539133.py:53: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '14' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   results.loc[results.index.str.contains('mmse'), 'N'] = str(df_sel.mmse.notna().sum())
# /tmp/ipykernel_3391179/2773539133.py:53: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '11' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   results.loc[results.index.str.contains('mmse'), 'N'] = str(df_sel.mmse.notna().sum())
# PARTIAL_PEARSONR
# ('slowdelta_bandpower_total', 'vol-ctx--anterior'), N=87: -0.126, 2.50E-1
# ('slowdelta_bandpower_total', 'vol-thalamus'), N=87: -0.071, 5.19E-1
# ('so_rate_f', 'vol-ctx--anterior'), N=87: -0.154, 1.60E-1
# ('so_rate_f', 'vol-thalamus'), N=87: -0.106, 3.36E-1
# N = 87
#
# PEARSONR
# ('ss_dens_f', 'vol-thalamus'), N=87: 0.328, 1.90E-3
# ('ss_dens_f', 'vol-hippocampus'), N=87: -0.026, 8.10E-1
# ('fs_dens_c', 'vol-thalamus'), N=87: 0.275, 9.86E-3
# ('fs_dens_c', 'vol-hippocampus'), N=87: 0.004, 9.71E-1
#
# PARTIAL_PEARSONR
# ('ss_dens_f', 'vol-thalamus'), N=87: 0.172, 1.15E-1
# ('ss_dens_f', 'vol-hippocampus'), N=87: -0.138, 2.08E-1
# ('fs_dens_c', 'vol-thalamus'), N=87: 0.171, 1.18E-1
# ('fs_dens_c', 'vol-hippocampus'), N=87: -0.074, 4.99E-1
# N = 87
#
# PEARSONR
# ('perc_r', 'vol-ctx--isthmuscingulate'), N=87: 0.1, 3.57E-1
# ('perc_r', 'vol-amygdala'), N=87: -0.011, 9.19E-1
# ('perc_r', 'vol-brain-stem'), N=87: -0.002, 9.82E-1
#
# PARTIAL_PEARSONR
# ('perc_r', 'vol-ctx--isthmuscingulate'), N=87: 0.08, 4.68E-1
# ('perc_r', 'vol-amygdala'), N=87: -0.046, 6.75E-1
# ('perc_r', 'vol-brain-stem'), N=87: 0.007, 9.51E-1
# N = 87
#
# PEARSONR
# ('alpha_bandpower_mean_o_w', 'vol-thalamus'), N=87: -0.045, 6.82E-1
# ('alpha_bandpower_mean_o_w', 'vol-total_ventricle'), N=87: 0.225, 3.65E-2
#
# PARTIAL_PEARSONR
# ('alpha_bandpower_mean_o_w', 'vol-thalamus'), N=87: 0.042, 7.04E-1
# ('alpha_bandpower_mean_o_w', 'vol-total_ventricle'), N=87: 0.176, 1.07E-1
#
# PEARSONR
# ('slowdelta_bandpower_total', 'mmse'), N=13: 0.074, 8.09E-1
# ('so_rate_f', 'mmse'), N=13: -0.092, 7.65E-1
# ('vol-ctx--anterior', 'mmse'), N=13: 0.106, 7.30E-1
# ('vol-thalamus', 'mmse'), N=13: 0.55, 5.14E-2
#
# PARTIAL_PEARSONR
# ('slowdelta_bandpower_total', 'mmse'), N=13: 0.08, 8.16E-1
# ('so_rate_f', 'mmse'), N=13: -0.071, 8.36E-1
# ('vol-ctx--anterior', 'mmse'), N=13: 0.099, 7.73E-1
# ('vol-thalamus', 'mmse'), N=13: 0.436, 1.81E-1
#
# PEARSONR
# ('ss_dens_f', 'mmse'), N=13: 0.147, 6.31E-1
# ('fs_dens_c', 'mmse'), N=13: 0.05, 8.72E-1
# ('vol-thalamus', 'mmse'), N=13: 0.55, 5.14E-2
# ('vol-hippocampus', 'mmse'), N=13: 0.133, 6.64E-1
#
# PARTIAL_PEARSONR
# ('ss_dens_f', 'mmse'), N=13: -0.116, 7.33E-1
# ('fs_dens_c', 'mmse'), N=13: -0.177, 6.02E-1
# ('vol-thalamus', 'mmse'), N=13: 0.436, 1.81E-1
# ('vol-hippocampus', 'mmse'), N=13: 0.074, 8.28E-1
#
# PEARSONR
# ('perc_r', 'mmse'), N=13: 0.328, 2.74E-1
# ('vol-ctx--isthmuscingulate', 'mmse'), N=13: 0.025, 9.35E-1
# ('vol-amygdala', 'mmse'), N=13: 0.405, 1.70E-1
# ('vol-brain-stem', 'mmse'), N=13: 0.136, 6.57E-1
#
# PARTIAL_PEARSONR
# ('perc_r', 'mmse'), N=13: 0.314, 3.47E-1
# ('vol-ctx--isthmuscingulate', 'mmse'), N=13: 0.407, 2.14E-1
# ('vol-amygdala', 'mmse'), N=13: 0.345, 2.98E-1
# ('vol-brain-stem', 'mmse'), N=13: 0.063, 8.53E-1
#
# PEARSONR
# ('alpha_bandpower_mean_o_w', 'mmse'), N=13: -0.321, 2.85E-1
# ('vol-thalamus', 'mmse'), N=13: 0.55, 5.14E-2
# ('vol-total_ventricle', 'mmse'), N=13: -0.497, 8.41E-2
#
# PARTIAL_PEARSONR
# ('alpha_bandpower_mean_o_w', 'mmse'), N=13: -0.261, 4.38E-1
# ('vol-thalamus', 'mmse'), N=13: 0.436, 1.81E-1
# ('vol-total_ventricle', 'mmse'), N=13: -0.313, 3.48E-1
#                                                     r pearsonr  p pearsonr  \
# ('slowdelta_bandpower_total', 'vol-ctx--anterior')    0.019491     0.85779
# ('slowdelta_bandpower_total', 'vol-thalamus')         0.245175     0.02209
#
#                                                     r partial_pearsonr  \
# ('slowdelta_bandpower_total', 'vol-ctx--anterior')           -0.126078
# ('slowdelta_bandpower_total', 'vol-thalamus')                -0.070888
#
#                                                     p partial_pearsonr   N  \
# ('slowdelta_bandpower_total', 'vol-ctx--anterior')            0.250240  87
# ('slowdelta_bandpower_total', 'vol-thalamus')                 0.519129  87
#
#                                                    age statistic % female
# ('slowdelta_bandpower_total', 'vol-ctx--anterior')   64.7 (10.9)     0.47
# ('slowdelta_bandpower_total', 'vol-thalamus')        64.7 (10.9)     0.47
# N = 136
#
# PEARSONR
# ('slowdelta_bandpower_total', 'vol-ctx--anterior'), N=136: 0.168, 5.04E-2
# ('slowdelta_bandpower_total', 'vol-thalamus'), N=136: 0.282, 8.81E-4
# ('so_rate_f', 'vol-ctx--anterior'), N=136: 0.128, 1.36E-1
# ('so_rate_f', 'vol-thalamus'), N=136: 0.243, 4.37E-3
#
# PARTIAL_PEARSONR
# ('slowdelta_bandpower_total', 'vol-ctx--anterior'), N=136: 0.011, 8.98E-1
# ('slowdelta_bandpower_total', 'vol-thalamus'), N=136: -0.079, 3.66E-1
# ('so_rate_f', 'vol-ctx--anterior'), N=136: -0.015, 8.63E-1
# ('so_rate_f', 'vol-thalamus'), N=136: -0.081, 3.50E-1
# N = 136
#
# PEARSONR
# ('ss_dens_f', 'vol-thalamus'), N=136: 0.194, 2.37E-2
# ('ss_dens_f', 'vol-hippocampus'), N=136: 0.092, 2.85E-1
# ('fs_dens_c', 'vol-thalamus'), N=136: 0.301, 3.62E-4
# ('fs_dens_c', 'vol-hippocampus'), N=136: 0.22, 1.00E-2
#
# PARTIAL_PEARSONR
# ('ss_dens_f', 'vol-thalamus'), N=136: 0.017, 8.43E-1
# ('ss_dens_f', 'vol-hippocampus'), N=136: 0.024, 7.82E-1
# ('fs_dens_c', 'vol-thalamus'), N=136: 0.091, 2.95E-1
# ('fs_dens_c', 'vol-hippocampus'), N=136: 0.144, 9.76E-2
# N = 136
#
# PEARSONR
# ('perc_r', 'vol-ctx--isthmuscingulate'), N=136: 0.041, 6.38E-1
# ('perc_r', 'vol-amygdala'), N=136: -0.014, 8.71E-1
# ('perc_r', 'vol-brain-stem'), N=136: -0.013, 8.78E-1
#
# PARTIAL_PEARSONR
# ('perc_r', 'vol-ctx--isthmuscingulate'), N=136: 0.058, 5.03E-1
# ('perc_r', 'vol-amygdala'), N=136: -0.069, 4.26E-1
# ('perc_r', 'vol-brain-stem'), N=136: -0.027, 7.59E-1
# N = 136
#
# PEARSONR
# ('alpha_bandpower_mean_o_w', 'vol-thalamus'), N=136: 0.096, 2.67E-1
# ('alpha_bandpower_mean_o_w', 'vol-total_ventricle'), N=136: 0.033, 7.07E-1
#
# PARTIAL_PEARSONR
# ('alpha_bandpower_mean_o_w', 'vol-thalamus'), N=136: 0.073, 4.00E-1
# ('alpha_bandpower_mean_o_w', 'vol-total_ventricle'), N=136: 0.073, 4.02E-1
#
# PEARSONR
# ('slowdelta_bandpower_total', 'mmse'), N=23: 0.129, 5.58E-1
# ('so_rate_f', 'mmse'), N=23: 0.157, 4.75E-1
# ('vol-ctx--anterior', 'mmse'), N=23: 0.021, 9.23E-1
# ('vol-thalamus', 'mmse'), N=23: 0.201, 3.58E-1
#
# PARTIAL_PEARSONR
# ('slowdelta_bandpower_total', 'mmse'), N=23: -0.183, 4.26E-1
# ('so_rate_f', 'mmse'), N=23: -0.135, 5.61E-1
# ('vol-ctx--anterior', 'mmse'), N=23: 0.047, 8.39E-1
# ('vol-thalamus', 'mmse'), N=23: -0.004, 9.85E-1
#
# PEARSONR
# ('ss_dens_f', 'mmse'), N=23: 0.329, 1.26E-1
# ('fs_dens_c', 'mmse'), N=23: 0.24, 2.69E-1
# ('vol-thalamus', 'mmse'), N=23: 0.201, 3.58E-1
# ('vol-hippocampus', 'mmse'), N=23: 0.019, 9.33E-1
#
# PARTIAL_PEARSONR
# ('ss_dens_f', 'mmse'), N=23: 0.355, 1.15E-1
# ('fs_dens_c', 'mmse'), N=23: 0.271, 2.35E-1
# ('vol-thalamus', 'mmse'), N=23: -0.004, 9.85E-1
# ('vol-hippocampus', 'mmse'), N=23: -0.037, 8.73E-1
#
# PEARSONR
# ('perc_r', 'mmse'), N=23: 0.294, 1.73E-1
# ('vol-ctx--isthmuscingulate', 'mmse'), N=23: -0.049, 8.25E-1
# ('vol-amygdala', 'mmse'), N=23: 0.229, 2.94E-1
# ('vol-brain-stem', 'mmse'), N=23: -0.087, 6.93E-1
#
# PARTIAL_PEARSONR
# ('perc_r', 'mmse'), N=23: 0.257, 2.61E-1
# ('vol-ctx--isthmuscingulate', 'mmse'), N=23: 0.066, 7.76E-1
# ('vol-amygdala', 'mmse'), N=23: 0.24, 2.95E-1
# ('vol-brain-stem', 'mmse'), N=23: -0.246, 2.82E-1
#
# PEARSONR
# ('alpha_bandpower_mean_o_w', 'mmse'), N=23: -0.149, 4.97E-1
# ('vol-thalamus', 'mmse'), N=23: 0.201, 3.58E-1
# ('vol-total_ventricle', 'mmse'), N=23: 0.132, 5.48E-1
#
# PARTIAL_PEARSONR
# ('alpha_bandpower_mean_o_w', 'mmse'), N=23: -0.06, 7.96E-1
# ('vol-thalamus', 'mmse'), N=23: -0.004, 9.85E-1
# ('vol-total_ventricle', 'mmse'), N=23: 0.329, 1.45E-1
#                                                     r pearsonr  p pearsonr  \
# ('slowdelta_bandpower_total', 'vol-ctx--anterior')    0.168129    0.050400
# ('slowdelta_bandpower_total', 'vol-thalamus')         0.282001    0.000881
#
#                                                     r partial_pearsonr  \
# ('slowdelta_bandpower_total', 'vol-ctx--anterior')            0.011205
# ('slowdelta_bandpower_total', 'vol-thalamus')                -0.078627
#
#                                                     p partial_pearsonr    N  \
# ('slowdelta_bandpower_total', 'vol-ctx--anterior')            0.897756  136
# ('slowdelta_bandpower_total', 'vol-thalamus')                 0.366499  136
#
#                                                    age statistic % female
# ('slowdelta_bandpower_total', 'vol-ctx--anterior')   63.1 (10.8)     0.52
# ('slowdelta_bandpower_total', 'vol-thalamus')        63.1 (10.8)     0.52
# N = 240
#
# PEARSONR
# ('slowdelta_bandpower_total', 'vol-ctx--anterior'), N=240: 0.125, 5.31E-2
# ('slowdelta_bandpower_total', 'vol-thalamus'), N=240: 0.237, 2.06E-4
# /tmp/ipykernel_3391179/2773539133.py:53: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '13' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   results.loc[results.index.str.contains('mmse'), 'N'] = str(df_sel.mmse.notna().sum())
# /tmp/ipykernel_3391179/2773539133.py:53: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '23' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   results.loc[results.index.str.contains('mmse'), 'N'] = str(df_sel.mmse.notna().sum())
# ('so_rate_f', 'vol-ctx--anterior'), N=240: 0.078, 2.26E-1
# ('so_rate_f', 'vol-thalamus'), N=240: 0.204, 1.45E-3
#
# PARTIAL_PEARSONR
# ('slowdelta_bandpower_total', 'vol-ctx--anterior'), N=240: 0.029, 6.61E-1
# ('slowdelta_bandpower_total', 'vol-thalamus'), N=240: -0.019, 7.75E-1
# ('so_rate_f', 'vol-ctx--anterior'), N=240: 0.006, 9.28E-1
# ('so_rate_f', 'vol-thalamus'), N=240: 0.024, 7.10E-1
# N = 240
#
# PEARSONR
# ('ss_dens_f', 'vol-thalamus'), N=240: 0.142, 2.80E-2
# ('ss_dens_f', 'vol-hippocampus'), N=240: 0.085, 1.90E-1
# ('fs_dens_c', 'vol-thalamus'), N=240: 0.328, 1.98E-7
# ('fs_dens_c', 'vol-hippocampus'), N=240: 0.16, 1.31E-2
#
# PARTIAL_PEARSONR
# ('ss_dens_f', 'vol-thalamus'), N=240: 0.013, 8.38E-1
# ('ss_dens_f', 'vol-hippocampus'), N=240: 0.009, 8.93E-1
# ('fs_dens_c', 'vol-thalamus'), N=240: 0.149, 2.12E-2
# ('fs_dens_c', 'vol-hippocampus'), N=240: 0.046, 4.82E-1
# N = 240
#
# PEARSONR
# ('perc_r', 'vol-ctx--isthmuscingulate'), N=240: -0.035, 5.87E-1
# ('perc_r', 'vol-amygdala'), N=240: 0.059, 3.63E-1
# ('perc_r', 'vol-brain-stem'), N=240: 0.051, 4.31E-1
#
# PARTIAL_PEARSONR
# ('perc_r', 'vol-ctx--isthmuscingulate'), N=240: -0.036, 5.81E-1
# ('perc_r', 'vol-amygdala'), N=240: 0.04, 5.44E-1
# ('perc_r', 'vol-brain-stem'), N=240: 0.051, 4.33E-1
# N = 240
#
# PEARSONR
# ('alpha_bandpower_mean_o_w', 'vol-thalamus'), N=240: 0.084, 1.96E-1
# ('alpha_bandpower_mean_o_w', 'vol-total_ventricle'), N=240: -0.09, 1.66E-1
#
# PARTIAL_PEARSONR
# ('alpha_bandpower_mean_o_w', 'vol-thalamus'), N=240: 0.047, 4.69E-1
# ('alpha_bandpower_mean_o_w', 'vol-total_ventricle'), N=240: -0.063, 3.31E-1
#
# PEARSONR
# ('slowdelta_bandpower_total', 'mmse'), N=61: 0.013, 9.22E-1
# ('so_rate_f', 'mmse'), N=61: 0.018, 8.92E-1
# ('vol-ctx--anterior', 'mmse'), N=61: -0.021, 8.71E-1
# ('vol-thalamus', 'mmse'), N=61: 0.158, 2.24E-1
#
# PARTIAL_PEARSONR
# ('slowdelta_bandpower_total', 'mmse'), N
-1
#
# PARTIAL_PEARSONR
# ('ss_dens_f', 'vol-thalamus'), N=131: 0.007, 9.33E-1
# ('ss_dens_f', 'vol-hippocampus'), N=131: 0.036, 6.86E-1
# ('fs_dens_c', 'vol-thalamus'), N=131: 0.057, 5.19E-1
# ('fs_dens_c', 'vol-hippocampus'), N=131: 0.028, 7.51E-1
# N = 131
#
# PEARSONR
# ('perc_r', 'vol-ctx--isthmuscingulate'), N=131: -0.017, 8.50E-1
# ('perc_r', 'vol-amygdala'), N=131: 0.152, 8.36E-2
# ('perc_r', 'vol-brain-stem'), N=131: 0.181, 3.90E-2
#
# PARTIAL_PEARSONR
# ('perc_r', 'vol-ctx--isthmuscingulate'), N=131: -0.021, 8.10E-1
# ('perc_r', 'vol-amygdala'), N=131: 0.114, 1.98E-1
# ('perc_r', 'vol-brain-stem'), N=131: 0.222, 1.13E-2
# N = 131
#
# PEARSONR
# ('alpha_bandpower_mean_o_w', 'vol-thalamus'), N=131: 0.083, 3.48E-1
# ('alpha_bandpower_mean_o_w', 'vol-total_ventricle'), N=131: -0.108, 2.20E-1
#
# PARTIAL_PEARSONR
# ('alpha_bandpower_mean_o_w', 'vol-thalamus'), N=131: 0.035, 6.93E-1
# ('alpha_bandpower_mean_o_w', 'vol-total_ventricle'), N=131: -0.072, 4.18E-1
#
# PEARSONR
# ('slowdelta_bandpower_total', 'mmse'), N=15: -0.292, 2.90E-1
# ('so_rate_f', 'mmse'), N=15: -0.401, 1.38E-1
# ('vol-ctx--anterior', 'mmse'), N=15: -0.054, 8.49E-1
# ('vol-thalamus', 'mmse'), N=15: 0.043, 8.80E-1
#
# PARTIAL_PEARSONR
# ('slowdelta_bandpower_total', 'mmse'), N=15: -0.241, 4.29E-1
# ('so_rate_f', 'mmse'), N=15: -0.39, 1.87E-1
# ('vol-ctx--anterior', 'mmse'), N=15: -0.02, 9.47E-1
# ('vol-thalamus', 'mmse'), N=15: 0.121, 6.94E-1
#
# PEARSONR
# ('ss_dens_f', 'mmse'), N=15: 0.068, 8.09E-1
# ('fs_dens_c', 'mmse'), N=15: 0.012, 9.66E-1
# ('vol-thalamus', 'mmse'), N=15: 0.043, 8.80E-1
# ('vol-hippocampus', 'mmse'), N=15: 0.253, 3.64E-1
#
# PARTIAL_PEARSONR
# ('ss_dens_f', 'mmse'), N=15: 0.259, 3.92E-1
# ('fs_dens_c', 'mmse'), N=15: 0.206, 5.00E-1
# ('vol-thalamus', 'mmse'), N=15: 0.121, 6.94E-1
# ('vol-hippocampus', 'mmse'), N=15: 0.256, 3.98E-1
# /tmp/ipykernel_3391179/2773539133.py:53: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '21' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   results.loc[results.index.str.contains('mmse'), 'N'] = str(df_sel.mmse.notna().sum())
# /tmp/ipykernel_3391179/2773539133.py:53: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '15' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   results.loc[results.index.str.contains('mmse'), 'N'] = str(df_sel.mmse.notna().sum())
# PEARSONR
# ('perc_r', 'mmse'), N=15: -0.121, 6.67E-1
# ('vol-ctx--isthmuscingulate', 'mmse'), N=15: 0.224, 4.23E-1
# ('vol-amygdala', 'mmse'), N=15: 0.373, 1.70E-1
# ('vol-brain-stem', 'mmse'), N=15: 0.172, 5.40E-1
#
# PARTIAL_PEARSONR
# ('perc_r', 'mmse'), N=15: -0.203, 5.06E-1
# ('vol-ctx--isthmuscingulate', 'mmse'), N=15: 0.301, 3.18E-1
# ('vol-amygdala', 'mmse'), N=15: 0.412, 1.61E-1
# ('vol-brain-stem', 'mmse'), N=15: 0.183, 5.50E-1
#
# PEARSONR
# ('alpha_bandpower_mean_o_w', 'mmse'), N=15: -0.376, 1.67E-1
# ('vol-thalamus', 'mmse'), N=15: 0.043, 8.80E-1
# ('vol-total_ventricle', 'mmse'), N=15: -0.341, 2.14E-1
#
# PARTIAL_PEARSONR
# ('alpha_bandpower_mean_o_w', 'mmse'), N=15: -0.344, 2.50E-1
# ('vol-thalamus', 'mmse'), N=15: 0.121, 6.94E-1
# ('vol-total_ventricle', 'mmse'), N=15: -0.416, 1.58E-1
#                                                     r pearsonr  p pearsonr  \
# ('slowdelta_bandpower_total', 'vol-ctx--anterior')    0.112282    0.201656
# ('slowdelta_bandpower_total', 'vol-thalamus')         0.188443    0.031122
#
#                                                     r partial_pearsonr  \
# ('slowdelta_bandpower_total', 'vol-ctx--anterior')           -0.014687
# ('slowdelta_bandpower_total', 'vol-thalamus')                -0.137004
#
#                                                     p partial_pearsonr    N  \
# ('slowdelta_bandpower_total', 'vol-ctx--anterior')            0.868791  131
# ('slowdelta_bandpower_total', 'vol-thalamus')                 0.121566  131
#
#                                                    age statistic % female
# ('slowdelta_bandpower_total', 'vol-ctx--anterior')   56.6 (12.9)     0.49
# ('slowdelta_bandpower_total', 'vol-thalamus')        56.6 (12.9)     0.49
# N = 86
#
# PEARSONR
# ('slowdelta_bandpower_total', 'vol-ctx--anterior'), N=86: 0.108, 3.22E-1
# ('slowdelta_bandpower_total', 'vol-thalamus'), N=86: 0.172, 1.14E-1
# ('so_rate_f', 'vol-ctx--anterior'), N=86: 0.128, 2.41E-1
# ('so_rate_f', 'vol-thalamus'), N=86: 0.175, 1.07E-1
#
# PARTIAL_PEARSONR
# ('slowdelta_bandpower_total', 'vol-ctx--anterior'), N=86: 0.057, 6.06E-1
# ('slowdelta_bandpower_total', 'vol-thalamus'), N=86: -0.082, 4.59E-1
# ('so_rate_f', 'vol-ctx--anterior'), N=86: 0.077, 4.89E-1
# ('so_rate_f', 'vol-thalamus'), N=86: -0.096, 3.85E-1
# N = 86
#
# PEARSONR
# ('ss_dens_f', 'vol-thalamus'), N=86: 0.074, 5.00E-1
# ('ss_dens_f', 'vol-hippocampus'), N=86: 0.047, 6.64E-1
# ('fs_dens_c', 'vol-thalamus'), N=86: 0.191, 7.80E-2
# ('fs_dens_c', 'vol-hippocampus'), N=86: -0.014, 8.97E-1
#
# PARTIAL_PEARSONR
# ('ss_dens_f', 'vol-thalamus'), N=86: 0.011, 9.23E-1
# ('ss_dens_f', 'vol-hippocampus'), N=86: 0.033, 7.65E-1
# ('fs_dens_c', 'vol-thalamus'), N=86: 0.082, 4.56E-1
# ('fs_dens_c', 'vol-hippocampus'), N=86: -0.044, 6.90E-1
# N = 86
#
# PEARSONR
# ('perc_r', 'vol-ctx--isthmuscingulate'), N=86: -0.047, 6.68E-1
# ('perc_r', 'vol-amygdala'), N=86: 0.1, 3.62E-1
# ('perc_r', 'vol-brain-stem'), N=86: 0.191, 7.79E-2
#
# PARTIAL_PEARSONR
# ('perc_r', 'vol-ctx--isthmuscingulate'), N=86: -0.02, 8.59E-1
# ('perc_r', 'vol-amygdala'), N=86: 0.061, 5.83E-1
# ('perc_r', 'vol-brain-stem'), N=86: 0.22, 4.45E-2
# N = 86
#
# PEARSONR
# ('alpha_bandpower_mean_o_w', 'vol-thalamus'), N=86: 0.036, 7.41E-1
# ('alpha_bandpower_mean_o_w', 'vol-total_ventricle'), N=86: -0.015, 8.90E-1
#
# PARTIAL_PEARSONR
# ('alpha_bandpower_mean_o_w', 'vol-thalamus'), N=86: -0.011, 9.18E-1
# ('alpha_bandpower_mean_o_w', 'vol-total_ventricle'), N=86: 0.036, 7.47E-1
#
# PEARSONR
# ('slowdelta_bandpower_total', 'mmse'), N=12: -0.306, 3.34E-1
# ('so_rate_f', 'mmse'), N=12: -0.439, 1.53E-1
# ('vol-ctx--anterior', 'mmse'), N=12: 0.064, 8.42E-1
# ('vol-thalamus', 'mmse'), N=12: 0.121, 7.08E-1
#
# PARTIAL_PEARSONR
# ('slowdelta_bandpower_total', 'mmse'), N=12: -0.338, 3.39E-1
# ('so_rate_f', 'mmse'), N=12: -0.531, 1.15E-1
# ('vol-ctx--anterior', 'mmse'), N=12: 0.064, 8.61E-1
# ('vol-thalamus', 'mmse'), N=12: 0.167, 6.46E-1
#
# PEARSONR
# ('ss_dens_f', 'mmse'), N=12: 0.033, 9.18E-1
# ('fs_dens_c', 'mmse'), N=12: 0.085, 7.92E-1
# ('vol-thalamus', 'mmse'), N=12: 0.121, 7.08E-1
# ('vol-hippocampus', 'mmse'), N=12: 0.395, 2.03E-1
#
# PARTIAL_PEARSONR
# ('ss_dens_f', 'mmse'), N=12: 0.195, 5.88E-1
# ('fs_dens_c', 'mmse'), N=12: 0.224, 5.34E-1
# ('vol-thalamus', 'mmse'), N=12: 0.167, 6.46E-1
# ('vol-hippocampus', 'mmse'), N=12: 0.42, 2.26E-1
#
# PEARSONR
# ('perc_r', 'mmse'), N=12: -0.204, 5.25E-1
# ('vol-ctx--isthmuscingulate', 'mmse'), N=12: 0.299, 3.45E-1
# ('vol-amygdala', 'mmse'), N=12: 0.508, 9.20E-2
# ('vol-brain-stem', 'mmse'), N=12: 0.263, 4.09E-1
#
# PARTIAL_PEARSONR
# ('perc_r', 'mmse'), N=12: -0.292, 4.12E-1
# ('vol-ctx--isthmuscingulate', 'mmse'), N=12: 0.387, 2.69E-1
# ('vol-amygdala', 'mmse'), N=12: 0.556, 9.53E-2
# ('vol-brain-stem', 'mmse'), N=12: 0.362, 3.03E-1
#
# PEARSONR
# ('alpha_bandpower_mean_o_w', 'mmse'), N=12: -0.367, 2.40E-1
# ('vol-thalamus', 'mmse'), N=12: 0.121, 7.08E-1
# ('vol-total_ventricle', 'mmse'), N=12: -0.412, 1.83E-1
#
# PARTIAL_PEARSONR
# ('alpha_bandpower_mean_o_w', 'mmse'), N=12: -0.341, 3.35E-1
# ('vol-thalamus', 'mmse'), N=12: 0.167, 6.46E-1
# ('vol-total_ventricle', 'mmse'), N=12: -0.449, 1.93E-1
#                                                     r pearsonr  p pearsonr  \
# ('slowdelta_bandpower_total', 'vol-ctx--anterior')    0.108130    0.321691
# ('slowdelta_bandpower_total', 'vol-thalamus')         0.171556    0.114244
#
#                                                     r partial_pearsonr  \
# ('slowdelta_bandpower_total', 'vol-ctx--anterior')            0.057029
# ('slowdelta_bandpower_total', 'vol-thalamus')                -0.081810
#
#                                                     p partial_pearsonr   N  \
# ('slowdelta_bandpower_total', 'vol-ctx--anterior')            0.606364  86
# ('slowdelta_bandpower_total', 'vol-thalamus')                 0.459417  86
#
#                                                    age statistic % female
# ('slowdelta_bandpower_total', 'vol-ctx--anterior')   55.1 (12.1)      0.5
# ('slowdelta_bandpower_total', 'vol-thalamus')        55.1 (12.1)      0.5
# /tmp/ipykernel_3391179/2773539133.py:53: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '12' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   results.loc[results.index.str.contains('mmse'), 'N'] = str(df_sel.mmse.notna().sum())

# %%
df_multiindex.xs(key='dx_mci', level='group').head(2)
# Out:
#                                                     r pearsonr  p pearsonr  \
# feature_pair
# ('slowdelta_bandpower_total', 'vol-ctx--anterior')   -0.020299    0.866566
# ('slowdelta_bandpower_total', 'vol-thalamus')         0.225445    0.058714
#
#                                                     r partial_pearsonr  \
# feature_pair
# ('slowdelta_bandpower_total', 'vol-ctx--anterior')           -0.176919
# ('slowdelta_bandpower_total', 'vol-thalamus')                 0.003744
#
#                                                     p partial_pearsonr   N  \
# feature_pair
# ('slowdelta_bandpower_total', 'vol-ctx--anterior')            0.145876  71
# ('slowdelta_bandpower_total', 'vol-thalamus')                 0.975643  71
#
#                                                    age statistic % female
# feature_pair
# ('slowdelta_bandpower_total', 'vol-ctx--anterior')    68.0 (9.7)     0.48
# ('slowdelta_bandpower_total', 'vol-thalamus')         68.0 (9.7)     0.48

# %%
df_multiindex.xs(key="('vol-total_ventricle', 'mmse')", level='feature_pair')
# Out:
#                                r pearsonr  p pearsonr  r partial_pearsonr  \
# group
# dx_dementia                     -0.037253    0.865991            0.007995
# dx_mci                          -0.198915    0.145420           -0.156674
# dx_elix_depre_no_mci_dementia   -0.002292    0.986875            0.000872
# dx_cci_canc_no_mci_dementia      0.187745    0.402775            0.251612
# dx_cci_diab_no_mci_dementia      0.286783    0.320179            0.424514
# dx_cci_chf_no_mci_dementia      -0.076693    0.822663            0.036255
# dx_cci_pvd_no_mci_dementia      -0.496823    0.084138           -0.313166
# dx_cci_cevd_no_mci_dementia      0.132045    0.548114            0.329002
# dx_strata_cci<2                 -0.243677    0.058432           -0.134123
# dx_strata_cci2-4                -0.126750    0.347456           -0.026745
# dx_strata_cci>=5                -0.407261    0.066893           -0.304014
# dx_no_disease                   -0.341018    0.213543           -0.415900
# dx_no_disease_cci<2             -0.412013    0.183234           -0.449059
# zzz_blank                             NaN         NaN                 NaN
#
#                                p partial_pearsonr    N age statistic % female
# group
# dx_dementia                              0.972562   23   71.8 (12.2)     0.57
# dx_mci                                   0.262568   55   68.0 (10.1)     0.49
# dx_elix_depre_no_mci_dementia            0.995102   54   61.7 (10.6)     0.46
# dx_cci_canc_no_mci_dementia              0.284564   22    67.0 (9.3)     0.32
# dx_cci_diab_no_mci_dementia              0.168980   14    63.0 (8.1)     0.21
# dx_cci_chf_no_mci_dementia               0.926223   11   69.1 (10.6)     0.36
# dx_cci_pvd_no_mci_dementia               0.348384   13    67.1 (9.2)     0.15
# dx_cci_cevd_no_mci_dementia              0.145321   23   67.2 (10.6)     0.39
# dx_strata_cci<2                          0.311176   61   62.3 (11.9)     0.41
# dx_strata_cci2-4                         0.846316   57   66.8 (10.7)     0.49
# dx_strata_cci>=5                         0.205723   21   68.5 (10.7)     0.62
# dx_no_disease                            0.157520   15   59.2 (12.5)      0.4
# dx_no_disease_cci<2                      0.192955   12   60.5 (13.7)     0.33
# zzz_blank                                     NaN  NaN           NaN      NaN

# %%
df_multiindex.xs(key="('fs_dens_c', 'vol-thalamus')", level='feature_pair')
# Out:
#                                r pearsonr    p pearsonr  r partial_pearsonr  \
# group
# dx_dementia                      0.238382  1.614862e-01            0.187073
# dx_mci                           0.355451  2.350669e-03            0.091589
# dx_elix_depre_no_mci_dementia    0.319198  1.286560e-07            0.117272
# dx_cci_canc_no_mci_dementia      0.259723  3.190427e-03            0.191764
# dx_cci_diab_no_mci_dementia      0.275949  2.283128e-03            0.180344
# dx_cci_chf_no_mci_dementia       0.162995  1.539126e-01            0.012666
# dx_cci_pvd_no_mci_dementia       0.275277  9.864722e-03            0.170655
# dx_cci_cevd_no_mci_dementia      0.301449  3.619813e-04            0.091055
# dx_strata_cci<2                  0.328103  1.981122e-07            0.149371
# dx_strata_cci2-4                 0.290130  2.942582e-05            0.078841
# dx_strata_cci>=5                 0.183942  9.807808e-02            0.061285
# dx_no_disease                    0.179490  4.023192e-02            0.057344
# dx_no_disease_cci<2              0.191057  7.804585e-02            0.082372
# zzz_blank                             NaN           NaN                 NaN
#
#                                p partial_pearsonr    N age statistic % female
# group
# dx_dementia                              0.289418   36   73.3 (11.2)     0.58
# dx_mci                                   0.454177   71    68.0 (9.7)     0.48
# dx_elix_depre_no_mci_dementia            0.058977  262   57.8 (11.9)     0.66
# dx_cci_canc_no_mci_dementia              0.032164  127   64.5 (10.4)     0.46
# dx_cci_diab_no_mci_dementia              0.050674  120   60.6 (10.4)     0.53
# dx_cci_chf_no_mci_dementia               0.913525   78   65.4 (11.1)      0.5
# dx_cci_pvd_no_mci_dementia               0.118396   87   64.7 (10.9)     0.47
# dx_cci_cevd_no_mci_dementia              0.295403  136   63.1 (10.8)     0.52
# dx_strata_cci<2                          0.021155  240   56.9 (11.9)     0.55
# dx_strata_cci2-4                         0.268337  201   61.6 (12.6)     0.59
# dx_strata_cci>=5                         0.589176   82   65.4 (10.5)     0.48
# dx_no_disease                            0.518606  131   56.6 (12.9)     0.49
# dx_no_disease_cci<2                      0.456328   86   55.1 (12.1)      0.5
# zzz_blank                                     NaN  NaN           NaN      NaN

# %%
results
# Out:
#                                                     r pearsonr  p pearsonr  \
# ('slowdelta_bandpower_total', 'vol-ctx--anterior')    0.108130    0.321691
# ('slowdelta_bandpower_total', 'vol-thalamus')         0.171556    0.114244
# ('so_rate_f', 'vol-ctx--anterior')                    0.127650    0.241498
# ('so_rate_f', 'vol-thalamus')                         0.174846    0.107364
# ('ss_dens_f', 'vol-thalamus')                         0.073659    0.500304
# ('ss_dens_f', 'vol-hippocampus')                      0.047492    0.664129
# ('fs_dens_c', 'vol-thalamus')                         0.191057    0.078046
# ('fs_dens_c', 'vol-hippocampus')                     -0.014179    0.896904
# ('perc_r', 'vol-ctx--isthmuscingulate')              -0.046961    0.667660
# ('perc_r', 'vol-amygdala')                            0.099591    0.361598
# ('perc_r', 'vol-brain-stem')                          0.191158    0.077886
# ('alpha_bandpower_mean_o_w', 'vol-thalamus')          0.036167    0.740946
# ('alpha_bandpower_mean_o_w', 'vol-total_ventric...   -0.015065    0.890500
# ('slowdelta_bandpower_total', 'mmse')                -0.305678    0.333928
# ('so_rate_f', 'mmse')                                -0.438928    0.153434
# ('vol-ctx--anterior', 'mmse')                         0.064476    0.842205
# ('vol-thalamus', 'mmse')                              0.120937    0.708109
# ('ss_dens_f', 'mmse')                                 0.033478    0.917736
# ('fs_dens_c', 'mmse')                                 0.085240    0.792248
# ('vol-hippocampus', 'mmse')                           0.395383    0.203324
# ('perc_r', 'mmse')                                   -0.203675    0.525478
# ('vol-ctx--isthmuscingulate', 'mmse')                 0.298844    0.345393
# ('vol-amygdala', 'mmse')                              0.507645    0.092023
# ('vol-brain-stem', 'mmse')                            0.262922    0.409013
# ('alpha_bandpower_mean_o_w', 'mmse')                 -0.367347    0.240119
# ('vol-total_ventricle', 'mmse')                      -0.412013    0.183234
#
#                                                     r partial_pearsonr  \
# ('slowdelta_bandpower_total', 'vol-ctx--anterior')            0.057029
# ('slowdelta_bandpower_total', 'vol-thalamus')                -0.081810
# ('so_rate_f', 'vol-ctx--anterior')                            0.076599
# ('so_rate_f', 'vol-thalamus')                                -0.096034
# ('ss_dens_f', 'vol-thalamus')                                 0.010652
# ('ss_dens_f', 'vol-hippocampus')                              0.033065
# ('fs_dens_c', 'vol-thalamus')                                 0.082372
# ('fs_dens_c', 'vol-hippocampus')                             -0.044103
# ('perc_r', 'vol-ctx--isthmuscingulate')                      -0.019665
# ('perc_r', 'vol-amygdala')                                    0.060737
# ('perc_r', 'vol-brain-stem')                                  0.219808
# ('alpha_bandpower_mean_o_w', 'vol-thalamus')                 -0.011349
# ('alpha_bandpower_mean_o_w', 'vol-total_ventric...            0.035742
# ('slowdelta_bandpower_total', 'mmse')                        -0.338272
# ('so_rate_f', 'mmse')                                        -0.530648
# ('vol-ctx--anterior', 'mmse')                                 0.063888
# ('vol-thalamus', 'mmse')                                      0.166522
# ('ss_dens_f', 'mmse')                                         0.195457
# ('fs_dens_c', 'mmse')                                         0.224113
# ('vol-hippocampus', 'mmse')                                   0.420459
# ('perc_r', 'mmse')                                           -0.292363
# ('vol-ctx--isthmuscingulate', 'mmse')                         0.387189
# ('vol-amygdala', 'mmse')                                      0.555772
# ('vol-brain-stem', 'mmse')                                    0.362345
# ('alpha_bandpower_mean_o_w', 'mmse')                         -0.341146
# ('vol-total_ventricle', 'mmse')                              -0.449059
#
#                                                     p partial_pearsonr   N  \
# ('slowdelta_bandpower_total', 'vol-ctx--anterior')            0.606364  86
# ('slowdelta_bandpower_total', 'vol-thalamus')                 0.459417  86
# ('so_rate_f', 'vol-ctx--anterior')                            0.488597  86
# ('so_rate_f', 'vol-thalamus')                                 0.384855  86
# ('ss_dens_f', 'vol-thalamus')                                 0.923390  86
# ('ss_dens_f', 'vol-hippocampus')                              0.765252  86
# ('fs_dens_c', 'vol-thalamus')                                 0.456328  86
# ('fs_dens_c', 'vol-hippocampus')                              0.690375  86
# ('perc_r', 'vol-ctx--isthmuscingulate')                       0.859075  86
# ('perc_r', 'vol-amygdala')                                    0.583123  86
# ('perc_r', 'vol-brain-stem')                                  0.044534  86
# ('alpha_bandpower_mean_o_w', 'vol-thalamus')                  0.918394  86
# ('alpha_bandpower_mean_o_w', 'vol-total_ventric...            0.746868  86
# ('slowdelta_bandpower_total', 'mmse')                         0.339048  12
# ('so_rate_f', 'mmse')                                         0.114550  12
# ('vol-ctx--anterior', 'mmse')                                 0.860815  12
# ('vol-thalamus', 'mmse')                                      0.645668  12
# ('ss_dens_f', 'mmse')                                         0.588400  12
# ('fs_dens_c', 'mmse')                                         0.533642  12
# ('vol-hippocampus', 'mmse')                                   0.226325  12
# ('perc_r', 'mmse')                                            0.412375  12
# ('vol-ctx--isthmuscingulate', 'mmse')                         0.268985  12
# ('vol-amygdala', 'mmse')                                      0.095296  12
# ('vol-brain-stem', 'mmse')                                    0.303496  12
# ('alpha_bandpower_mean_o_w', 'mmse')                          0.334696  12
# ('vol-total_ventricle', 'mmse')                               0.192955  12
#
#                                                    age statistic % female
# ('slowdelta_bandpower_total', 'vol-ctx--anterior')   55.1 (12.1)      0.5
# ('slowdelta_bandpower_total', 'vol-thalamus')        55.1 (12.1)      0.5
# ('so_rate_f', 'vol-ctx--anterior')                   55.1 (12.1)      0.5
# ('so_rate_f', 'vol-thalamus')                        55.1 (12.1)      0.5
# ('ss_dens_f', 'vol-thalamus')                        55.1 (12.1)      0.5
# ('ss_dens_f', 'vol-hippocampus')                     55.1 (12.1)      0.5
# ('fs_dens_c', 'vol-thalamus')                        55.1 (12.1)      0.5
# ('fs_dens_c', 'vol-hippocampus')                     55.1 (12.1)      0.5
# ('perc_r', 'vol-ctx--isthmuscingulate')              55.1 (12.1)      0.5
# ('perc_r', 'vol-amygdala')                           55.1 (12.1)      0.5
# ('perc_r', 'vol-brain-stem')                         55.1 (12.1)      0.5
# ('alpha_bandpower_mean_o_w', 'vol-thalamus')         55.1 (12.1)      0.5
# ('alpha_bandpower_mean_o_w', 'vol-total_ventric...   55.1 (12.1)      0.5
# ('slowdelta_bandpower_total', 'mmse')                60.5 (13.7)     0.33
# ('so_rate_f', 'mmse')                                60.5 (13.7)     0.33
# ('vol-ctx--anterior', 'mmse')                        60.5 (13.7)     0.33
# ('vol-thalamus', 'mmse')                             60.5 (13.7)     0.33
# ('ss_dens_f', 'mmse')                                60.5 (13.7)     0.33
# ('fs_dens_c', 'mmse')                                60.5 (13.7)     0.33
# ('vol-hippocampus', 'mmse')                          60.5 (13.7)     0.33
# ('perc_r', 'mmse')                                   60.5 (13.7)     0.33
# ('vol-ctx--isthmuscingulate', 'mmse')                60.5 (13.7)     0.33
# ('vol-amygdala', 'mmse')                             60.5 (13.7)     0.33
# ('vol-brain-stem', 'mmse')                           60.5 (13.7)     0.33
# ('alpha_bandpower_mean_o_w', 'mmse')                 60.5 (13.7)     0.33
# ('vol-total_ventricle', 'mmse')                      60.5 (13.7)     0.33
